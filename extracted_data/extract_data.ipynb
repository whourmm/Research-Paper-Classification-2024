# %%
import os
import json
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import csv
import pandas as pd

# %% [markdown]
# ### (Don't need to run this command I've already done for you) Extracted Link From the Given Json
# This part is for extracting the specific link that contain "scopus.com" but exclude "citedby"
#
# Example Link with <a href="https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85170238281&origin=inward">"citedby"</a> : <br>
# <div style="text-align: center;">
#   <img src="../image/with_citeby.png" alt="image" width="1000" height="500">
# </div>
# </br>
# Example Link without <a href="https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85050336797&origin=inward">"citedby"</a> : <br>
# <div style="text-align: center;">
#   <img src="../image/without_citeby.png" alt="image" width="1000" height="500">
# </div>

# %%
def extract_scopus_links(data, links=None):
    """
    Recursively extract all Scopus links from a JSON object, excluding those with 'citedbyresults'.
    """
    if links is None:
        links = set()

    if isinstance(data, dict):
        for key, value in data.items():
            extract_scopus_links(value, links)
    elif isinstance(data, list):
        for item in data:
            extract_scopus_links(item, links)
    elif isinstance(data, str) and "scopus.com" in data and "citedby" not in data:
        links.add(data)

    return links

def save_links_to_files(links, output_base, max_links_per_file):
    """
    Save links to multiple files, each containing up to `max_links_per_file` links.
    """
    links = list(links)
    total_links = len(links)
    num_files = (total_links // max_links_per_file) + (1 if total_links % max_links_per_file != 0 else 0)

    for i in range(num_files):
        start_idx = i * max_links_per_file
        end_idx = start_idx + max_links_per_file
        chunk_links = links[start_idx:end_idx]

        output_file = f"{output_base}_{i + 1}.txt"
        # Use utf-8 encoding when writing to the file
        with open(output_file, 'w', encoding='utf-8') as outfile:
            outfile.write("\n".join(chunk_links))
        print(f"Saved {len(chunk_links)} links to {output_file}.")

def process_folders(base_folder, output_base, max_links_per_file=200):
    """
    Process all files in subfolders, extracting Scopus links from files containing JSON content.
    """
    collected_links = set()

    # Walk through each folder and file
    for root, dirs, files in os.walk(base_folder):
        for file in files:
            file_path = os.path.join(root, file)
            print(f"Processing folder: {root} | File: {file}")  # Print current folder and file being processed
            try:
                # Try to open and parse the file as JSON, even if it's not a .json file
                with open(file_path, 'r', encoding='utf-8') as f:
                    try:
                        # Try loading the content as JSON
                        json_data = json.load(f)

                        # Extract Scopus links
                        links = extract_scopus_links(json_data)
                        collected_links.update(links)
                    except json.JSONDecodeError:
                        # If the file content is not valid JSON, print a message
                        print(f"Skipping file (not valid JSON): {file_path}")
            except Exception as e:
                print(f"Error processing {file_path}: {e}")

    # Save collected links to multiple files
    save_links_to_files(collected_links, output_base, max_links_per_file)

# Step 1: Specify the folder where the extracted files are located
base_folder = '../Project'  # Replace with the path to your extracted files

# Step 2: Define the output base name for the link files
output_base = 'scopus_links_2023'  # Base name for output files

# Step 3: Process the folder and extract Scopus links, splitting into files with 200 links each
process_folders(base_folder, output_base, max_links_per_file=200)

# Step 4: Notify that the files are saved
print(f"Scopus links have been saved in batches with a maximum of 200 links per file.")
# Out:
# Processing folder: ../Project\2023 | File: 202300000
# Processing folder: ../Project\2023 | File: 202300001
# Processing folder: ../Project\2023 | File: 202300002
# Processing folder: ../Project\2023 | File: 202300003
# Processing folder: ../Project\2023 | File: 202300004
# Processing folder: ../Project\2023 | File: 202300005
# Processing folder: ../Project\2023 | File: 202300006
# Processing folder: ../Project\2023 | File: 202300007
# Processing folder: ../Project\2023 | File: 202300008
# Processing folder: ../Project\2023 | File: 202302862
# Processing folder: ../Project\2023 | File: 202302863
# Processing folder: ../Project\2023 | File: 202302864
# Processing folder: ../Project\2023 | File: 202302865
# Processing folder: ../Project\2023 | File: 202302866
# Processing folder: ../Project\2023 | File: 202302867
# Processing folder: ../Project\2023 | File: 202302868
# Processing folder: ../Project\2023 | File: 202302869
# Processing folder: ../Project\2023 | File: 202302870
# Processing folder: ../Project\2023 | File: 202302871
# Processing folder: ../Project\2023 | File: 202302872
# Processing folder: ../Project\2023 | File: 202302873
# Processing folder: ../Project\2023 | File: 202302874
# Processing folder: ../Project\2023 | File: 202302875
# Processing folder: ../Project\2023 | File: 202302876
# Processing folder: ../Project\2023 | File: 202302877
# Processing folder: ../Project\2023 | File: 202302878
# Processing folder: ../Project\2023 | File: 202302879
# Processing folder: ../Project\2023 | File: 202302880
# Processing folder: ../Project\2023 | File: 202302881
# Processing folder: ../Project\2023 | File: 202302882
# Processing folder: ../Project\2023 | File: 202302883
# Processing folder: ../Project\2023 | File: 202302884
# Processing folder: ../Project\2023 | File: 202302885
# Processing folder: ../Project\2023 | File: 202302886
# Processing folder: ../Project\2023 | File: 202302887
# Processing folder: ../Project\2023 | File: 202302888
# Processing folder: ../Project\2023 | File: 202302889
# Saved 200 links to scopus_links_2023_1.txt.
# Saved 200 links to scopus_links_2023_2.txt.
# Saved 200 links to scopus_links_2023_3.txt.
# Saved 200 links to scopus_links_2023_4.txt.
# Saved 200 links to scopus_links_2023_5.txt.
# Saved 200 links to scopus_links_2023_6.txt.
# Saved 200 links to scopus_links_2023_7.txt.
# Saved 200 links to scopus_links_2023_8.txt.
# Saved 200 links to scopus_links_2023_9.txt.
# Saved 200 links to scopus_links_2023_10.txt.
# Saved 200 links to scopus_links_2023_11.txt.
# Saved 200 links to scopus_links_2023_12.txt.
# Saved 200 links to scopus_links_2023_13.txt.
# Saved 200 links to scopus_links_2023_14.txt.
# Saved 93 links to scopus_links_2023_15.txt.
# Scopus links have been saved in batches with a maximum of 200 links per file.

# %% [markdown]
# ### WebScrapping from the extracted link
# This part is for scraaping data including:
# - title
# - authors
# - article_info
# - abstract
# - categories/keyword
# - citation_info
# - document_info
# - author_tags
# - affiliations
# - funding
#
# <div style="text-align: center;">
#   <img src="../image/label_1.png" alt="image" width="1000" height="500">
# </div>
# <div style="text-align: center;">
#   <img src="../image/label_2.png" alt="image" width="1000" height="500">
# </div>

# %%
def extract_data(url):
    # print("twet")
    print(f"Opening page: {url}")  # Print progress as soon as the page starts loading
    chrome_options = Options()
    chrome_options.add_argument("--disable-gpu")  # Disable GPU acceleration (useful for some environments)

# Specify path to chromedriver if necessary, e.g., 'path/to/chromedriver'
    # driver = webdriver.Chrome(executable_path=r"C:\Users\admin\Downloads\chromedriver-win64\chromedriver.exe", options=chrome_options)
    driver = webdriver.Chrome(service=Service(r"C:\Users\admin\Downloads\chromedriver-win64\chromedriver.exe"))
    
    try: 

        driver.get(url)
        soup = BeautifulSoup(driver.page_source, "lxml")
        data = {}

        # Extraction logic (same as your provided code)
        h2_elements = soup.select('h2')
        for h2 in h2_elements:
            inner_text = h2.get_text(strip=True)
            data["title"] = inner_text if inner_text else ""

        author_section = soup.find('section', {'id': 'authorlist'})
        if author_section:
            author_tags = author_section.find_all('span', {'class': 'previewTxt'})
            authors = [author_tag.get_text(strip=True) for author_tag in author_tags if author_tag.get_text(strip=True)]
            data["authors"] = authors if authors else []
        else:
            data["authors"] = []

        journal_info_span = soup.find('span', {'id': 'journalInfo'})
        data["article_info"] = journal_info_span.get_text(strip=True) if journal_info_span else ""

        abstract_section = soup.find('section', {'id': 'abstractSection'})
        if abstract_section:
            p_tag = abstract_section.find('p')
            data["abstract"] = p_tag.get_text(strip=True) if p_tag else ""
        else:
            data["abstract"] = ""

        span_tag = soup.find('span', {'id': 'guestAccessSourceTitle'})
        data["categories/keyword"] = span_tag.get_text(strip=True) if span_tag else ""

        citation_ul = soup.find('ul', {'id': 'citationInfo'})
        citation_info = {}
        citation_fields = ["ISSN", "Source Type", "Original Language"]
        if citation_ul:
            li_tags = citation_ul.find_all('li')
            for i, li in enumerate(li_tags):
                strong_tag = li.find('strong')
                if strong_tag:
                    strong_tag.extract()
                clean_text = li.get_text(strip=True)
                if i < len(citation_fields):
                    citation_info[citation_fields[i]] = clean_text
        data["citation_info"] = citation_info

        document_ul = soup.find('ul', {'id': 'documentInfo'})
        document_info = {}
        document_fields = ["Document Type", "Publisher"]
        if document_ul:
            li_tags = document_ul.find_all('li')
            for i, li in enumerate(li_tags):
                strong_tag = li.find('strong')
                if strong_tag:
                    strong_tag.extract()
                clean_text = li.get_text(strip=True)
                if i < len(document_fields):
                    document_info[document_fields[i]] = clean_text
        data["document_info"] = document_info if document_info else {}

        author_tags = soup.find_all('span', {'class': 'badges'})
        authors = [author_tag.get_text(strip=True) for author_tag in author_tags if author_tag.get_text(strip=True)]
        data["author_tags"] = authors if authors else []

        affiliation_section = soup.find('section', {'id': 'affiliationlist'})
        if affiliation_section:
            affiliation_tags = affiliation_section.find_all('li')
            affiliations = [affiliation_tag.get_text(strip=True) for affiliation_tag in affiliation_tags if affiliation_tag.get_text(strip=True)]
            data["affiliations"] = affiliations if affiliations else []
        else:
            data["affiliations"] = []

        funding_rows = soup.find_all('tr', {'class': 'lightGreyBorderBottom'})
        funding_data = []
        for funding_row in funding_rows:
            td_tags = funding_row.find_all('td')
            funding_info = {"Funding Sponsor": "", "Funding Number": "", "Acronym": ""}
            if len(td_tags) >= 3:
                funding_info["Funding Sponsor"] = td_tags[0].get_text(strip=True) if td_tags[0] else ""
                funding_info["Funding Number"] = td_tags[1].get_text(strip=True) if td_tags[1] else ""
                funding_info["Acronym"] = td_tags[2].get_text(strip=True) if td_tags[2] else ""
            funding_data.append(funding_info)
        data["funding"] = funding_data if funding_data else []
    except Exception as e:
        print(f"Error scraping {url}: {e}")  # Log errors during scraping
        data = {}
    finally:
        driver.quit()
    print(f"Finished scraping: {url}")  # Notify when scraping for this URL is complete
    return data

# %% [markdown]
# ### Run This Command
# 1. Change ADD "ADD PATH/TO/.TXT" to the selected file path
# 2. Change the output file name

# %%
with open('data/extracted_2019/scopus_links_2019.txt_16.txt', 'r') as file:
    urls = [line.strip() for line in file if line.strip()]

# Test only the first 5 links
total_urls = len(urls)
test_urls = urls
# print(total_urls)

# Extract data from the test URLs
all_data = []

for index, test_urls in enumerate(test_urls , start=1):
    print(f"\nProcessing URL {index}/{total_urls}...")
    try:
        extracted_data = extract_data(test_urls)  # Calls the function that now shows progress as pages open
        all_data.append(extracted_data)
    except Exception as e:
        print(f"Error processing URL {test_urls}: {e}")
    print(f"Completed URL {index}/{total_urls}.")

# Convert data to a pandas DataFrame
df = pd.DataFrame(all_data)

# Save to a CSV file
df.to_csv('test_output.csv', index=False)

print("Data extraction complete. Saved to output.csv.")
# Out:
# Processing URL 1/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85087225912&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85087225912&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85087225912&origin=inward
# Completed URL 1/87.
#
# Processing URL 2/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062345412&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062345412&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062345412&origin=inward
# Completed URL 2/87.
#
# Processing URL 3/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069180565&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069180565&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069180565&origin=inward
# Completed URL 3/87.
#
# Processing URL 4/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065545013&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065545013&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065545013&origin=inward
# Completed URL 4/87.
#
# Processing URL 5/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078505871&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078505871&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078505871&origin=inward
# Completed URL 5/87.
#
# Processing URL 6/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076341221&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076341221&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076341221&origin=inward
# Completed URL 6/87.
#
# Processing URL 7/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063902132&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063902132&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063902132&origin=inward
# Completed URL 7/87.
#
# Processing URL 8/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85079188760&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85079188760&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85079188760&origin=inward
# Completed URL 8/87.
#
# Processing URL 9/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073694205&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073694205&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073694205&origin=inward
# Completed URL 9/87.
#
# Processing URL 10/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066460744&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066460744&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066460744&origin=inward
# Completed URL 10/87.
#
# Processing URL 11/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072691758&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072691758&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072691758&origin=inward
# Completed URL 11/87.
#
# Processing URL 12/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062777627&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062777627&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062777627&origin=inward
# Completed URL 12/87.
#
# Processing URL 13/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066604503&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066604503&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066604503&origin=inward
# Completed URL 13/87.
#
# Processing URL 14/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073474269&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073474269&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073474269&origin=inward
# Completed URL 14/87.
#
# Processing URL 15/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064175216&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064175216&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064175216&origin=inward
# Completed URL 15/87.
#
# Processing URL 16/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075113874&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075113874&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075113874&origin=inward
# Completed URL 16/87.
#
# Processing URL 17/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072014235&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072014235&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072014235&origin=inward
# Completed URL 17/87.
#
# Processing URL 18/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074226436&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074226436&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074226436&origin=inward
# Completed URL 18/87.
#
# Processing URL 19/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85058857761&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85058857761&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85058857761&origin=inward
# Completed URL 19/87.
#
# Processing URL 20/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85055904330&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85055904330&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85055904330&origin=inward
# Completed URL 20/87.
#
# Processing URL 21/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85059661943&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85059661943&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85059661943&origin=inward
# Completed URL 21/87.
#
# Processing URL 22/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075983230&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075983230&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075983230&origin=inward
# Completed URL 22/87.
#
# Processing URL 23/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072307352&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072307352&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072307352&origin=inward
# Completed URL 23/87.
#
# Processing URL 24/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85083381937&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85083381937&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85083381937&origin=inward
# Completed URL 24/87.
#
# Processing URL 25/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85061251641&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85061251641&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85061251641&origin=inward
# Completed URL 25/87.
#
# Processing URL 26/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070118070&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070118070&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070118070&origin=inward
# Completed URL 26/87.
#
# Processing URL 27/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070330622&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070330622&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070330622&origin=inward
# Completed URL 27/87.
#
# Processing URL 28/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075630712&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075630712&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075630712&origin=inward
# Completed URL 28/87.
#
# Processing URL 29/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85077073854&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85077073854&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85077073854&origin=inward
# Completed URL 29/87.
#
# Processing URL 30/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074889372&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074889372&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074889372&origin=inward
# Completed URL 30/87.
#
# Processing URL 31/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062897997&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062897997&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062897997&origin=inward
# Completed URL 31/87.
#
# Processing URL 32/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85077153764&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85077153764&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85077153764&origin=inward
# Completed URL 32/87.
#
# Processing URL 33/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064441106&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064441106&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064441106&origin=inward
# Completed URL 33/87.
#
# Processing URL 34/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066066510&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066066510&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066066510&origin=inward
# Completed URL 34/87.
#
# Processing URL 35/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067672334&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067672334&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067672334&origin=inward
# Completed URL 35/87.
#
# Processing URL 36/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074667265&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074667265&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074667265&origin=inward
# Completed URL 36/87.
#
# Processing URL 37/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064011109&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064011109&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064011109&origin=inward
# Completed URL 37/87.
#
# Processing URL 38/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85056157314&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85056157314&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85056157314&origin=inward
# Completed URL 38/87.
#
# Processing URL 39/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063298432&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063298432&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063298432&origin=inward
# Completed URL 39/87.
#
# Processing URL 40/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073876153&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073876153&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073876153&origin=inward
# Completed URL 40/87.
#
# Processing URL 41/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064834284&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064834284&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064834284&origin=inward
# Completed URL 41/87.
#
# Processing URL 42/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069293544&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069293544&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069293544&origin=inward
# Completed URL 42/87.
#
# Processing URL 43/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062975770&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062975770&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062975770&origin=inward
# Completed URL 43/87.
#
# Processing URL 44/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068122411&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068122411&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068122411&origin=inward
# Completed URL 44/87.
#
# Processing URL 45/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073570158&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073570158&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073570158&origin=inward
# Completed URL 45/87.
#
# Processing URL 46/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073874865&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073874865&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073874865&origin=inward
# Completed URL 46/87.
#
# Processing URL 47/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070872915&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070872915&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070872915&origin=inward
# Completed URL 47/87.
#
# Processing URL 48/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074338081&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074338081&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074338081&origin=inward
# Completed URL 48/87.
#
# Processing URL 49/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069942029&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069942029&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069942029&origin=inward
# Completed URL 49/87.
#
# Processing URL 50/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067863785&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067863785&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067863785&origin=inward
# Completed URL 50/87.
#
# Processing URL 51/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85017461017&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85017461017&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85017461017&origin=inward
# Completed URL 51/87.
#
# Processing URL 52/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064611930&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064611930&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064611930&origin=inward
# Completed URL 52/87.
#
# Processing URL 53/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067280484&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067280484&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067280484&origin=inward
# Completed URL 53/87.
#
# Processing URL 54/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073507038&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073507038&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073507038&origin=inward
# Completed URL 54/87.
#
# Processing URL 55/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075915068&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075915068&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075915068&origin=inward
# Completed URL 55/87.
#
# Processing URL 56/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070745231&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070745231&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070745231&origin=inward
# Completed URL 56/87.
#
# Processing URL 57/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068692668&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068692668&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068692668&origin=inward
# Completed URL 57/87.
#
# Processing URL 58/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067491861&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067491861&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067491861&origin=inward
# Completed URL 58/87.
#
# Processing URL 59/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85045839157&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85045839157&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85045839157&origin=inward
# Completed URL 59/87.
#
# Processing URL 60/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060345023&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060345023&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060345023&origin=inward
# Completed URL 60/87.
#
# Processing URL 61/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85077055575&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85077055575&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85077055575&origin=inward
# Completed URL 61/87.
#
# Processing URL 62/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070735961&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070735961&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070735961&origin=inward
# Completed URL 62/87.
#
# Processing URL 63/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85077774167&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85077774167&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85077774167&origin=inward
# Completed URL 63/87.
#
# Processing URL 64/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078172194&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078172194&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078172194&origin=inward
# Completed URL 64/87.
#
# Processing URL 65/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069267290&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069267290&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069267290&origin=inward
# Completed URL 65/87.
#
# Processing URL 66/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064051384&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064051384&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064051384&origin=inward
# Completed URL 66/87.
#
# Processing URL 67/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073033253&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073033253&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073033253&origin=inward
# Completed URL 67/87.
#
# Processing URL 68/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074277455&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074277455&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074277455&origin=inward
# Completed URL 68/87.
#
# Processing URL 69/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075329057&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075329057&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075329057&origin=inward
# Completed URL 69/87.
#
# Processing URL 70/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064138325&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064138325&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064138325&origin=inward
# Completed URL 70/87.
#
# Processing URL 71/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068135526&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068135526&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068135526&origin=inward
# Completed URL 71/87.
#
# Processing URL 72/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066762715&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066762715&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066762715&origin=inward
# Completed URL 72/87.
#
# Processing URL 73/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063617126&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063617126&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063617126&origin=inward
# Completed URL 73/87.
#
# Processing URL 74/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078017389&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078017389&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078017389&origin=inward
# Completed URL 74/87.
#
# Processing URL 75/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85092051828&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85092051828&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85092051828&origin=inward
# Completed URL 75/87.
#
# Processing URL 76/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069055320&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069055320&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069055320&origin=inward
# Completed URL 76/87.
#
# Processing URL 77/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060756283&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060756283&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060756283&origin=inward
# Completed URL 77/87.
#
# Processing URL 78/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071437292&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071437292&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071437292&origin=inward
# Completed URL 78/87.
#
# Processing URL 79/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073259336&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073259336&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073259336&origin=inward
# Completed URL 79/87.
#
# Processing URL 80/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075848777&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075848777&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075848777&origin=inward
# Completed URL 80/87.
#
# Processing URL 81/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062528852&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062528852&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062528852&origin=inward
# Completed URL 81/87.
#
# Processing URL 82/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85056386047&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85056386047&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85056386047&origin=inward
# Completed URL 82/87.
#
# Processing URL 83/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074310364&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074310364&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074310364&origin=inward
# Completed URL 83/87.
#
# Processing URL 84/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073083806&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073083806&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073083806&origin=inward
# Completed URL 84/87.
#
# Processing URL 85/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066508614&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066508614&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066508614&origin=inward
# Completed URL 85/87.
#
# Processing URL 86/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067811502&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067811502&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067811502&origin=inward
# Completed URL 86/87.
#
# Processing URL 87/87...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85081093214&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85081093214&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85081093214&origin=inward
# Completed URL 87/87.
# Data extraction complete. Saved to output.csv.

# %%
# Folder containing the .txt files
folder_path = 'data/extracted_2019'  # Change to your folder path

# List all .txt files in the folder
txt_files = [f for f in os.listdir(folder_path) if f.endswith('.txt')]

# Iterate through each .txt file
for txt_file in txt_files:
    file_path = os.path.join(folder_path, txt_file)

    # Open and read URLs from the current file
    with open(file_path, 'r') as file:
        urls = [line.strip() for line in file if line.strip()]

    total_urls = len(urls)
    print(f"Processing file: {txt_file} with {total_urls} URLs.")

    all_data = []  # Collect all data for this file

    # Extract data from the URLs in the current file
    for index, url in enumerate(urls, start=1):
        print(f"\nProcessing URL {index}/{total_urls}...")
        try:
            # Extract data for the current URL
            extracted_data = extract_data(url)  # Calls the function that shows progress
            all_data.append(extracted_data)
        except Exception as e:
            print(f"Error processing URL {url}: {e}")
        print(f"Completed URL {index}/{total_urls}.")

    # Convert extracted data into a pandas DataFrame
    df = pd.DataFrame(all_data)

    # Define the output file name based on the .txt file
    output_file = os.path.join(folder_path, f"{os.path.splitext(txt_file)[0]}_output.csv")

    # Save the extracted data to the output CSV file
    df.to_csv(output_file, index=False)

    print(f"Data extraction for {txt_file} complete. Saved to {output_file}.")
    
print("All files processed successfully.")
# Out:
# Processing file: scopus_links_2019.txt_1.txt with 200 URLs.
#
# Processing URL 1/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85046023620&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85046023620&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85046023620&origin=inward
# Completed URL 1/200.
#
# Processing URL 2/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076265509&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076265509&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076265509&origin=inward
# Completed URL 2/200.
#
# Processing URL 3/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062640972&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062640972&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062640972&origin=inward
# Completed URL 3/200.
#
# Processing URL 4/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063279122&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063279122&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063279122&origin=inward
# Completed URL 4/200.
#
# Processing URL 5/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069550026&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069550026&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069550026&origin=inward
# Completed URL 5/200.
#
# Processing URL 6/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85085863218&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85085863218&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85085863218&origin=inward
# Completed URL 6/200.
#
# Processing URL 7/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85061512111&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85061512111&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85061512111&origin=inward
# Completed URL 7/200.
#
# Processing URL 8/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064326204&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064326204&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064326204&origin=inward
# Completed URL 8/200.
#
# Processing URL 9/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070777695&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070777695&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070777695&origin=inward
# Completed URL 9/200.
#
# Processing URL 10/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065557033&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065557033&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065557033&origin=inward
# Completed URL 10/200.
#
# Processing URL 11/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076229169&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076229169&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076229169&origin=inward
# Completed URL 11/200.
#
# Processing URL 12/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069928663&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069928663&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069928663&origin=inward
# Completed URL 12/200.
#
# Processing URL 13/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067179317&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067179317&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067179317&origin=inward
# Completed URL 13/200.
#
# Processing URL 14/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85083001886&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85083001886&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85083001886&origin=inward
# Completed URL 14/200.
#
# Processing URL 15/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85056447778&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85056447778&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85056447778&origin=inward
# Completed URL 15/200.
#
# Processing URL 16/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064633801&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064633801&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064633801&origin=inward
# Completed URL 16/200.
#
# Processing URL 17/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071913626&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071913626&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071913626&origin=inward
# Completed URL 17/200.
#
# Processing URL 18/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85082508161&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85082508161&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85082508161&origin=inward
# Completed URL 18/200.
#
# Processing URL 19/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070786691&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070786691&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070786691&origin=inward
# Completed URL 19/200.
#
# Processing URL 20/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070547689&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070547689&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070547689&origin=inward
# Completed URL 20/200.
#
# Processing URL 21/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074147634&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074147634&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074147634&origin=inward
# Completed URL 21/200.
#
# Processing URL 22/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076212323&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076212323&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076212323&origin=inward
# Completed URL 22/200.
#
# Processing URL 23/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073571196&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073571196&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073571196&origin=inward
# Completed URL 23/200.
#
# Processing URL 24/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063267165&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063267165&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063267165&origin=inward
# Completed URL 24/200.
#
# Processing URL 25/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062321467&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062321467&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062321467&origin=inward
# Completed URL 25/200.
#
# Processing URL 26/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075350487&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075350487&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075350487&origin=inward
# Completed URL 26/200.
#
# Processing URL 27/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063605347&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063605347&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063605347&origin=inward
# Completed URL 27/200.
#
# Processing URL 28/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060377219&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060377219&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060377219&origin=inward
# Completed URL 28/200.
#
# Processing URL 29/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85057772904&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85057772904&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85057772904&origin=inward
# Completed URL 29/200.
#
# Processing URL 30/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85085520572&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85085520572&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85085520572&origin=inward
# Completed URL 30/200.
#
# Processing URL 31/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85082515751&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85082515751&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85082515751&origin=inward
# Completed URL 31/200.
#
# Processing URL 32/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060328060&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060328060&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060328060&origin=inward
# Completed URL 32/200.
#
# Processing URL 33/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85061243135&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85061243135&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85061243135&origin=inward
# Completed URL 33/200.
#
# Processing URL 34/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070255341&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070255341&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070255341&origin=inward
# Completed URL 34/200.
#
# Processing URL 35/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85079616477&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85079616477&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85079616477&origin=inward
# Completed URL 35/200.
#
# Processing URL 36/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067811443&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067811443&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067811443&origin=inward
# Completed URL 36/200.
#
# Processing URL 37/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062186210&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062186210&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062186210&origin=inward
# Completed URL 37/200.
#
# Processing URL 38/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076179600&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076179600&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076179600&origin=inward
# Completed URL 38/200.
#
# Processing URL 39/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062521369&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062521369&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062521369&origin=inward
# Completed URL 39/200.
#
# Processing URL 40/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165214033&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165214033&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165214033&origin=inward
# Completed URL 40/200.
#
# Processing URL 41/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067076748&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067076748&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067076748&origin=inward
# Completed URL 41/200.
#
# Processing URL 42/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070566526&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070566526&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070566526&origin=inward
# Completed URL 42/200.
#
# Processing URL 43/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073330994&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073330994&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073330994&origin=inward
# Completed URL 43/200.
#
# Processing URL 44/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065074990&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065074990&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065074990&origin=inward
# Completed URL 44/200.
#
# Processing URL 45/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85051725467&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85051725467&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85051725467&origin=inward
# Completed URL 45/200.
#
# Processing URL 46/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068990653&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068990653&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068990653&origin=inward
# Completed URL 46/200.
#
# Processing URL 47/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066434744&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066434744&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066434744&origin=inward
# Completed URL 47/200.
#
# Processing URL 48/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065533444&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065533444&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065533444&origin=inward
# Completed URL 48/200.
#
# Processing URL 49/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064176690&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064176690&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064176690&origin=inward
# Completed URL 49/200.
#
# Processing URL 50/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064055894&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064055894&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064055894&origin=inward
# Completed URL 50/200.
#
# Processing URL 51/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074756059&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074756059&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074756059&origin=inward
# Completed URL 51/200.
#
# Processing URL 52/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070777727&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070777727&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070777727&origin=inward
# Completed URL 52/200.
#
# Processing URL 53/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069699539&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069699539&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069699539&origin=inward
# Completed URL 53/200.
#
# Processing URL 54/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85082699817&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85082699817&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85082699817&origin=inward
# Completed URL 54/200.
#
# Processing URL 55/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073741734&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073741734&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073741734&origin=inward
# Completed URL 55/200.
#
# Processing URL 56/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85079452584&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85079452584&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85079452584&origin=inward
# Completed URL 56/200.
#
# Processing URL 57/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072365396&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072365396&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072365396&origin=inward
# Completed URL 57/200.
#
# Processing URL 58/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85054041750&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85054041750&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85054041750&origin=inward
# Completed URL 58/200.
#
# Processing URL 59/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062102028&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062102028&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062102028&origin=inward
# Completed URL 59/200.
#
# Processing URL 60/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066828572&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066828572&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066828572&origin=inward
# Completed URL 60/200.
#
# Processing URL 61/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85056834636&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85056834636&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85056834636&origin=inward
# Completed URL 61/200.
#
# Processing URL 62/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074733082&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074733082&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074733082&origin=inward
# Completed URL 62/200.
#
# Processing URL 63/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067939815&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067939815&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067939815&origin=inward
# Completed URL 63/200.
#
# Processing URL 64/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071767741&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071767741&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071767741&origin=inward
# Completed URL 64/200.
#
# Processing URL 65/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078421248&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078421248&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078421248&origin=inward
# Completed URL 65/200.
#
# Processing URL 66/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062040129&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062040129&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062040129&origin=inward
# Completed URL 66/200.
#
# Processing URL 67/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075033033&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075033033&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075033033&origin=inward
# Completed URL 67/200.
#
# Processing URL 68/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065803082&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065803082&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065803082&origin=inward
# Completed URL 68/200.
#
# Processing URL 69/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073089044&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073089044&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073089044&origin=inward
# Completed URL 69/200.
#
# Processing URL 70/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078111250&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078111250&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078111250&origin=inward
# Completed URL 70/200.
#
# Processing URL 71/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065494200&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065494200&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065494200&origin=inward
# Completed URL 71/200.
#
# Processing URL 72/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062904772&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062904772&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062904772&origin=inward
# Completed URL 72/200.
#
# Processing URL 73/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072257805&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072257805&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072257805&origin=inward
# Completed URL 73/200.
#
# Processing URL 74/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067216416&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067216416&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067216416&origin=inward
# Completed URL 74/200.
#
# Processing URL 75/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071011313&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071011313&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071011313&origin=inward
# Completed URL 75/200.
#
# Processing URL 76/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063423092&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063423092&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063423092&origin=inward
# Completed URL 76/200.
#
# Processing URL 77/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062869108&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062869108&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062869108&origin=inward
# Completed URL 77/200.
#
# Processing URL 78/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078139291&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078139291&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85078139291&origin=inward
# Completed URL 78/200.
#
# Processing URL 79/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062046983&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062046983&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062046983&origin=inward
# Completed URL 79/200.
#
# Processing URL 80/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060305259&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060305259&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060305259&origin=inward
# Completed URL 80/200.
#
# Processing URL 81/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074424246&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074424246&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074424246&origin=inward
# Completed URL 81/200.
#
# Processing URL 82/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071672724&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071672724&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071672724&origin=inward
# Completed URL 82/200.
#
# Processing URL 83/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85052110437&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85052110437&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85052110437&origin=inward
# Completed URL 83/200.
#
# Processing URL 84/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069267978&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069267978&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069267978&origin=inward
# Completed URL 84/200.
#
# Processing URL 85/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068115256&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068115256&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068115256&origin=inward
# Completed URL 85/200.
#
# Processing URL 86/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064212558&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064212558&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064212558&origin=inward
# Completed URL 86/200.
#
# Processing URL 87/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069663308&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069663308&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069663308&origin=inward
# Completed URL 87/200.
#
# Processing URL 88/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073331437&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073331437&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073331437&origin=inward
# Completed URL 88/200.
#
# Processing URL 89/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075814075&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075814075&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075814075&origin=inward
# Completed URL 89/200.
#
# Processing URL 90/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067133708&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067133708&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067133708&origin=inward
# Completed URL 90/200.
#
# Processing URL 91/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064394773&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064394773&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064394773&origin=inward
# Completed URL 91/200.
#
# Processing URL 92/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062639795&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062639795&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062639795&origin=inward
# Completed URL 92/200.
#
# Processing URL 93/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074370726&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074370726&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074370726&origin=inward
# Completed URL 93/200.
#
# Processing URL 94/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068355745&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068355745&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068355745&origin=inward
# Completed URL 94/200.
#
# Processing URL 95/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066106976&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066106976&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066106976&origin=inward
# Completed URL 95/200.
#
# Processing URL 96/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060188313&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060188313&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85060188313&origin=inward
# Completed URL 96/200.
#
# Processing URL 97/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075987177&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075987177&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075987177&origin=inward
# Completed URL 97/200.
#
# Processing URL 98/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85051025631&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85051025631&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85051025631&origin=inward
# Completed URL 98/200.
#
# Processing URL 99/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066940712&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066940712&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85066940712&origin=inward
# Completed URL 99/200.
#
# Processing URL 100/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065781381&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065781381&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065781381&origin=inward
# Completed URL 100/200.
#
# Processing URL 101/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85057610599&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85057610599&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# ...
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071600684&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071600684&origin=inward
# Completed URL 198/200.
#
# Processing URL 199/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076116576&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076116576&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076116576&origin=inward
# Completed URL 199/200.
#
# Processing URL 200/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073703491&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073703491&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073703491&origin=inward
# Completed URL 200/200.
# Data extraction for scopus_links_2019.txt_1.txt complete. Saved to data/extracted_2019\scopus_links_2019.txt_1_output.csv.
# Processing file: scopus_links_2019.txt_10.txt with 200 URLs.
#
# Processing URL 1/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065516567&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065516567&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065516567&origin=inward
# Completed URL 1/200.
#
# Processing URL 2/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064517213&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064517213&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064517213&origin=inward
# Completed URL 2/200.
#
# Processing URL 3/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073676593&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073676593&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85073676593&origin=inward
# Completed URL 3/200.
#
# Processing URL 4/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063280998&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063280998&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85063280998&origin=inward
# Completed URL 4/200.
#
# Processing URL 5/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071635409&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071635409&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85071635409&origin=inward
# Completed URL 5/200.
#
# Processing URL 6/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070232264&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070232264&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070232264&origin=inward
# Completed URL 6/200.
#
# Processing URL 7/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067998475&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067998475&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067998475&origin=inward
# Completed URL 7/200.
#
# Processing URL 8/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074189829&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074189829&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074189829&origin=inward
# Completed URL 8/200.
#
# Processing URL 9/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85134035104&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85134035104&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85134035104&origin=inward
# Completed URL 9/200.
#
# Processing URL 10/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070967460&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070967460&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85070967460&origin=inward
# Completed URL 10/200.
#
# Processing URL 11/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064041029&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064041029&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85064041029&origin=inward
# Completed URL 11/200.
#
# Processing URL 12/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85079600748&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85079600748&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85079600748&origin=inward
# Completed URL 12/200.
#
# Processing URL 13/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068537258&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068537258&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85068537258&origin=inward
# Completed URL 13/200.
#
# Processing URL 14/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074249647&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074249647&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074249647&origin=inward
# Completed URL 14/200.
#
# Processing URL 15/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069445628&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069445628&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85069445628&origin=inward
# Completed URL 15/200.
#
# Processing URL 16/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062107683&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062107683&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85062107683&origin=inward
# Completed URL 16/200.
#
# Processing URL 17/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85052484988&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85052484988&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85052484988&origin=inward
# Completed URL 17/200.
#
# Processing URL 18/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85065787724&origin=inward
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 25
#      22 print(f"\nProcessing URL {index}/{total_urls}...")
#      23 try:
#      24     # Extract data for the current URL
# ---> 25     extracted_data = extract_data(url)  # Calls the function that shows progress
#      26     all_data.append(extracted_data)
#      27 except Exception as e:
#
# Cell In[33], line 13, in extract_data(url)
#       9 driver = webdriver.Chrome(service=Service(r"C:\Users\admin\Downloads\chromedriver-win64\chromedriver.exe"))
#      11 try:
# ---> 13     driver.get(url)
#      14     soup = BeautifulSoup(driver.page_source, "lxml")
#      15     data = {}
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\site-packages\selenium\webdriver\remote\webdriver.py:389, in WebDriver.get(self, url)
#     387 def get(self, url: str) -> None:
#     388     """Loads a web page in the current browser session."""
# --> 389     self.execute(Command.GET, {"url": url})
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\site-packages\selenium\webdriver\remote\webdriver.py:378, in WebDriver.execute(self, driver_command, params)
#     375     elif "sessionId" not in params:
#     376         params["sessionId"] = self.session_id
# --> 378 response = self.command_executor.execute(driver_command, params)
#     379 if response:
#     380     self.error_handler.check_response(response)
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:391, in RemoteConnection.execute(self, command, params)
#     389 trimmed = self._trim_large_entries(params)
#     390 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 391 return self._request(command_info[0], url, body=data)
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:415, in RemoteConnection._request(self, method, url, body)
#     412     body = None
#     414 if self._client_config.keep_alive:
# --> 415     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     416     statuscode = response.status
#     417 else:
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\site-packages\urllib3\_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)
#     140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\site-packages\urllib3\_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\site-packages\urllib3\poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\admin\anaconda3\envs\DSDE-CEDT\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# KeyboardInterrupt:
