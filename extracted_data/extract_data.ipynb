# %%
import os
import json
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import csv
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import re

# %% [markdown]
# ### (Don't need to run this command I've already done for you) Extracted Link From the Given Json
# This part is for extracting the specific link that contain "scopus.com" but exclude "citedby"
#
# Example Link with <a href="https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85170238281&origin=inward">"citedby"</a> : <br>
# <div style="text-align: center;">
#   <img src="../image/with_citeby.png" alt="image" width="1000" height="500">
# </div>
# </br>
# Example Link without <a href="https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85050336797&origin=inward">"citedby"</a> : <br>
# <div style="text-align: center;">
#   <img src="../image/without_citeby.png" alt="image" width="1000" height="500">
# </div>

# %%
def extract_scopus_links(data, links=None):
    """
    Recursively extract all Scopus links from a JSON object, excluding those with 'citedbyresults'.
    """
    if links is None:
        links = set()

    if isinstance(data, dict):
        for key, value in data.items():
            extract_scopus_links(value, links)
    elif isinstance(data, list):
        for item in data:
            extract_scopus_links(item, links)
    elif isinstance(data, str) and "scopus.com" in data and "citedby" not in data:
        links.add(data)

    return links

def save_links_to_files(links, output_base, max_links_per_file):
    """
    Save links to multiple files, each containing up to `max_links_per_file` links.
    """
    links = list(links)
    total_links = len(links)
    num_files = (total_links // max_links_per_file) + (1 if total_links % max_links_per_file != 0 else 0)

    for i in range(num_files):
        start_idx = i * max_links_per_file
        end_idx = start_idx + max_links_per_file
        chunk_links = links[start_idx:end_idx]

        output_file = f"{output_base}_{i + 1}.txt"
        # Use utf-8 encoding when writing to the file
        with open(output_file, 'w', encoding='utf-8') as outfile:
            outfile.write("\n".join(chunk_links))
        print(f"Saved {len(chunk_links)} links to {output_file}.")

def process_folders(base_folder, output_base, max_links_per_file=200):
    """
    Process all files in subfolders, extracting Scopus links from files containing JSON content.
    """
    collected_links = set()

    # Walk through each folder and file
    for root, dirs, files in os.walk(base_folder):
        for file in files:
            file_path = os.path.join(root, file)
            print(f"Processing folder: {root} | File: {file}")  # Print current folder and file being processed
            try:
                # Try to open and parse the file as JSON, even if it's not a .json file
                with open(file_path, 'r', encoding='utf-8') as f:
                    try:
                        # Try loading the content as JSON
                        json_data = json.load(f)

                        # Extract Scopus links
                        links = extract_scopus_links(json_data)
                        collected_links.update(links)
                    except json.JSONDecodeError:
                        # If the file content is not valid JSON, print a message
                        print(f"Skipping file (not valid JSON): {file_path}")
            except Exception as e:
                print(f"Error processing {file_path}: {e}")

    # Save collected links to multiple files
    save_links_to_files(collected_links, output_base, max_links_per_file)

# Step 1: Specify the folder where the extracted files are located
base_folder = '../Project'  # Replace with the path to your extracted files

# Step 2: Define the output base name for the link files
output_base = 'scopus_links_2023'  # Base name for output files

# Step 3: Process the folder and extract Scopus links, splitting into files with 200 links each
process_folders(base_folder, output_base, max_links_per_file=200)

# Step 4: Notify that the files are saved
print(f"Scopus links have been saved in batches with a maximum of 200 links per file.")
# Out:
# Scopus links have been saved in batches with a maximum of 200 links per file.

# %% [markdown]
# ### WebScrapping from the extracted link
# This part is for scraaping data including:
# - title
# - authors
# - article_info
# - abstract
# - categories/keyword
# - citation_info
# - document_info
# - author_tags
# - affiliations
# - funding
#
# <div style="text-align: center;">
#   <img src="../image/label_1.png" alt="image" width="1000" height="500">
# </div>
# <div style="text-align: center;">
#   <img src="../image/label_2.png" alt="image" width="1000" height="500">
# </div>

# %%
def extract_data(url):
    print(f"Opening page: {url}")  # Print progress as soon as the page starts loading
    chrome_options = Options()
    chrome_options.add_argument("--disable-gpu")  # Disable GPU acceleration (useful for some environments)
    webdriver_path = r"C:\users\asus\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe"

# Create a Service object
    service = Service(webdriver_path)

# Optional: Add Chrome options if needed
    chrome_options = webdriver.ChromeOptions()
# Example: Add headless mode or other options
# chrome_options.add_argument("--headless")

# Initialize the WebDriver using the Service object
    driver = webdriver.Chrome(service=service, options=chrome_options)
    # webdriver_path = r"C:\Users\ASUS\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe"  # Update this to your actual WebDriver path

    # Use the WebDriver as usua


    try: 

        driver.get(url)
        soup = BeautifulSoup(driver.page_source, "lxml")
        data = {}

        # Extraction logic (same as your provided code)
        h2_elements = soup.select('h2')
        for h2 in h2_elements:
            inner_text = h2.get_text(strip=True)
            data["title"] = inner_text if inner_text else ""

        author_section = soup.find('section', {'id': 'authorlist'})
        if author_section:
            author_tags = author_section.find_all('span', {'class': 'previewTxt'})
            authors = [author_tag.get_text(strip=True) for author_tag in author_tags if author_tag.get_text(strip=True)]
            data["authors"] = authors if authors else []
        else:
            data["authors"] = []

        journal_info_span = soup.find('span', {'id': 'journalInfo'})
        data["article_info"] = journal_info_span.get_text(strip=True) if journal_info_span else ""

        abstract_section = soup.find('section', {'id': 'abstractSection'})
        if abstract_section:
            p_tag = abstract_section.find('p')
            data["abstract"] = p_tag.get_text(strip=True) if p_tag else ""
        else:
            data["abstract"] = ""

        span_tag = soup.find('span', {'id': 'guestAccessSourceTitle'})
        data["categories/keyword"] = span_tag.get_text(strip=True) if span_tag else ""

        citation_ul = soup.find('ul', {'id': 'citationInfo'})
        citation_info = {}
        citation_fields = ["ISSN", "Source Type", "Original Language"]
        if citation_ul:
            li_tags = citation_ul.find_all('li')
            for i, li in enumerate(li_tags):
                strong_tag = li.find('strong')
                if strong_tag:
                    strong_tag.extract()
                clean_text = li.get_text(strip=True)
                if i < len(citation_fields):
                    citation_info[citation_fields[i]] = clean_text
        data["citation_info"] = citation_info

        document_ul = soup.find('ul', {'id': 'documentInfo'})
        document_info = {}
        document_fields = ["Document Type", "Publisher"]
        if document_ul:
            li_tags = document_ul.find_all('li')
            for i, li in enumerate(li_tags):
                strong_tag = li.find('strong')
                if strong_tag:
                    strong_tag.extract()
                clean_text = li.get_text(strip=True)
                if i < len(document_fields):
                    document_info[document_fields[i]] = clean_text
        data["document_info"] = document_info if document_info else {}

        author_tags = soup.find_all('span', {'class': 'badges'})
        authors = [author_tag.get_text(strip=True) for author_tag in author_tags if author_tag.get_text(strip=True)]
        data["author_tags"] = authors if authors else []

        affiliation_section = soup.find('section', {'id': 'affiliationlist'})
        if affiliation_section:
            affiliation_tags = affiliation_section.find_all('li')
            affiliations = [affiliation_tag.get_text(strip=True) for affiliation_tag in affiliation_tags if affiliation_tag.get_text(strip=True)]
            data["affiliations"] = affiliations if affiliations else []
        else:
            data["affiliations"] = []

        funding_rows = soup.find_all('tr', {'class': 'lightGreyBorderBottom'})
        funding_data = []
        for funding_row in funding_rows:
            td_tags = funding_row.find_all('td')
            funding_info = {"Funding Sponsor": "", "Funding Number": "", "Acronym": ""}
            if len(td_tags) >= 3:
                funding_info["Funding Sponsor"] = td_tags[0].get_text(strip=True) if td_tags[0] else ""
                funding_info["Funding Number"] = td_tags[1].get_text(strip=True) if td_tags[1] else ""
                funding_info["Acronym"] = td_tags[2].get_text(strip=True) if td_tags[2] else ""
            funding_data.append(funding_info)
        data["funding"] = funding_data if funding_data else []
    except Exception as e:
        print(f"Error scraping {url}: {e}")  # Log errors during scraping
        data = {}
    finally:
        driver.quit()
    print(f"Finished scraping: {url}")  # Notify when scraping for this URL is complete
    return data

# %% [markdown]
# ### Run This Command
# 1. Change ADD "ADD PATH/TO/.TXT" to the selected file path
# 2. Change the output file name

# %%
# Folder containing the .txt files
folder_path = 'data/extracted_2023'  # Change to your folder path

# List all .txt files in the folder
txt_files = [f for f in os.listdir(folder_path) if f.endswith('.txt')]

# Iterate through each .txt file
for txt_file in txt_files:
    file_path = os.path.join(folder_path, txt_file)

    # Open and read URLs from the current file
    with open(file_path, 'r') as file:
        urls = [line.strip() for line in file if line.strip()]

    total_urls = len(urls)
    print(f"Processing file: {txt_file} with {total_urls} URLs.")

    all_data = []  # Collect all data for this file

    # Extract data from the URLs in the current file
    for index, url in enumerate(urls, start=1):
        print(f"\nProcessing URL {index}/{total_urls}...")
        try:
            # Extract data for the current URL
            extracted_data = extract_data(url)  # Calls the function that shows progress
            all_data.append(extracted_data)
        except Exception as e:
            print(f"Error processing URL {url}: {e}")
        print(f"Completed URL {index}/{total_urls}.")

    # Convert extracted data into a pandas DataFrame
    df = pd.DataFrame(all_data)

    # Define the output file name based on the .txt file
    output_file = os.path.join(folder_path, f"{os.path.splitext(txt_file)[0]}_output.csv")

    # Save the extracted data to the output CSV file
    df.to_csv(output_file, index=False)

    print(f"Data extraction for {txt_file} complete. Saved to {output_file}.")
    
print("All files processed successfully.")
# Out:
# Processing file: scopus_links_2023_1.txt with 200 URLs.
#
# Processing URL 1/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85168855206&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85168855206&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85168855206&origin=inward
# Completed URL 1/200.
#
# Processing URL 2/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163311811&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163311811&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163311811&origin=inward
# Completed URL 2/200.
#
# Processing URL 3/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159092223&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159092223&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159092223&origin=inward
# Completed URL 3/200.
#
# Processing URL 4/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85140489961&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85140489961&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85140489961&origin=inward
# Completed URL 4/200.
#
# Processing URL 5/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167568240&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167568240&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167568240&origin=inward
# Completed URL 5/200.
#
# Processing URL 6/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149753655&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149753655&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149753655&origin=inward
# Completed URL 6/200.
#
# Processing URL 7/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165284617&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165284617&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165284617&origin=inward
# Completed URL 7/200.
#
# Processing URL 8/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159607815&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159607815&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159607815&origin=inward
# Completed URL 8/200.
#
# Processing URL 9/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159130158&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159130158&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159130158&origin=inward
# Completed URL 9/200.
#
# Processing URL 10/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159758145&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159758145&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159758145&origin=inward
# Completed URL 10/200.
#
# Processing URL 11/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151168078&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151168078&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151168078&origin=inward
# Completed URL 11/200.
#
# Processing URL 12/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163814996&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163814996&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163814996&origin=inward
# Completed URL 12/200.
#
# Processing URL 13/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147793986&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147793986&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147793986&origin=inward
# Completed URL 13/200.
#
# Processing URL 14/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163656863&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163656863&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163656863&origin=inward
# Completed URL 14/200.
#
# Processing URL 15/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166125611&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166125611&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166125611&origin=inward
# Completed URL 15/200.
#
# Processing URL 16/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164490751&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164490751&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164490751&origin=inward
# Completed URL 16/200.
#
# Processing URL 17/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151993529&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151993529&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151993529&origin=inward
# Completed URL 17/200.
#
# Processing URL 18/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149417217&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149417217&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149417217&origin=inward
# Completed URL 18/200.
#
# Processing URL 19/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166563958&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166563958&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166563958&origin=inward
# Completed URL 19/200.
#
# Processing URL 20/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147208883&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147208883&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147208883&origin=inward
# Completed URL 20/200.
#
# Processing URL 21/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85137419881&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85137419881&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85137419881&origin=inward
# Completed URL 21/200.
#
# Processing URL 22/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152427767&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152427767&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152427767&origin=inward
# Completed URL 22/200.
#
# Processing URL 23/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163751138&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163751138&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163751138&origin=inward
# Completed URL 23/200.
#
# Processing URL 24/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150766843&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150766843&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150766843&origin=inward
# Completed URL 24/200.
#
# Processing URL 25/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85169298593&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85169298593&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85169298593&origin=inward
# Completed URL 25/200.
#
# Processing URL 26/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148743554&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148743554&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148743554&origin=inward
# Completed URL 26/200.
#
# Processing URL 27/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167465997&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167465997&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167465997&origin=inward
# Completed URL 27/200.
#
# Processing URL 28/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85144508450&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85144508450&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85144508450&origin=inward
# Completed URL 28/200.
#
# Processing URL 29/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85144058861&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85144058861&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85144058861&origin=inward
# Completed URL 29/200.
#
# Processing URL 30/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146921830&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146921830&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146921830&origin=inward
# Completed URL 30/200.
#
# Processing URL 31/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85160970129&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85160970129&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85160970129&origin=inward
# Completed URL 31/200.
#
# Processing URL 32/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85145828245&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85145828245&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85145828245&origin=inward
# Completed URL 32/200.
#
# Processing URL 33/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149452025&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149452025&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149452025&origin=inward
# Completed URL 33/200.
#
# Processing URL 34/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146803655&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146803655&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146803655&origin=inward
# Completed URL 34/200.
#
# Processing URL 35/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166577970&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166577970&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166577970&origin=inward
# Completed URL 35/200.
#
# Processing URL 36/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146364976&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146364976&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146364976&origin=inward
# Completed URL 36/200.
#
# Processing URL 37/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149307253&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149307253&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149307253&origin=inward
# Completed URL 37/200.
#
# Processing URL 38/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152786709&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152786709&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152786709&origin=inward
# Completed URL 38/200.
#
# Processing URL 39/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167844401&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167844401&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167844401&origin=inward
# Completed URL 39/200.
#
# Processing URL 40/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147290715&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147290715&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147290715&origin=inward
# Completed URL 40/200.
#
# Processing URL 41/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147805893&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147805893&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147805893&origin=inward
# Completed URL 41/200.
#
# Processing URL 42/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159464803&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159464803&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159464803&origin=inward
# Completed URL 42/200.
#
# Processing URL 43/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163646626&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163646626&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163646626&origin=inward
# Completed URL 43/200.
#
# Processing URL 44/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149241396&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149241396&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149241396&origin=inward
# Completed URL 44/200.
#
# Processing URL 45/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152895094&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152895094&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152895094&origin=inward
# Completed URL 45/200.
#
# Processing URL 46/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167705316&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167705316&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167705316&origin=inward
# Completed URL 46/200.
#
# Processing URL 47/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151480187&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151480187&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151480187&origin=inward
# Completed URL 47/200.
#
# Processing URL 48/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150665581&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150665581&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150665581&origin=inward
# Completed URL 48/200.
#
# Processing URL 49/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85153787295&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85153787295&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85153787295&origin=inward
# Completed URL 49/200.
#
# Processing URL 50/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150485310&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150485310&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150485310&origin=inward
# Completed URL 50/200.
#
# Processing URL 51/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164812523&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164812523&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164812523&origin=inward
# Completed URL 51/200.
#
# Processing URL 52/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159625549&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159625549&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85159625549&origin=inward
# Completed URL 52/200.
#
# Processing URL 53/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150311244&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150311244&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150311244&origin=inward
# Completed URL 53/200.
#
# Processing URL 54/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146246325&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146246325&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146246325&origin=inward
# Completed URL 54/200.
#
# Processing URL 55/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147272272&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147272272&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147272272&origin=inward
# Completed URL 55/200.
#
# Processing URL 56/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150413956&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150413956&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150413956&origin=inward
# Completed URL 56/200.
#
# Processing URL 57/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85169016059&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85169016059&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85169016059&origin=inward
# Completed URL 57/200.
#
# Processing URL 58/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85141993898&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85141993898&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85141993898&origin=inward
# Completed URL 58/200.
#
# Processing URL 59/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85118303218&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85118303218&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85118303218&origin=inward
# Completed URL 59/200.
#
# Processing URL 60/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166529583&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166529583&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166529583&origin=inward
# Completed URL 60/200.
#
# Processing URL 61/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85170291824&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85170291824&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85170291824&origin=inward
# Completed URL 61/200.
#
# Processing URL 62/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163716248&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163716248&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163716248&origin=inward
# Completed URL 62/200.
#
# Processing URL 63/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85168292139&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85168292139&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85168292139&origin=inward
# Completed URL 63/200.
#
# Processing URL 64/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85111325476&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85111325476&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85111325476&origin=inward
# Completed URL 64/200.
#
# Processing URL 65/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165015375&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165015375&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165015375&origin=inward
# Completed URL 65/200.
#
# Processing URL 66/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150844280&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150844280&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150844280&origin=inward
# Completed URL 66/200.
#
# Processing URL 67/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146088698&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146088698&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146088698&origin=inward
# Completed URL 67/200.
#
# Processing URL 68/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165403367&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165403367&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165403367&origin=inward
# Completed URL 68/200.
#
# Processing URL 69/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163765891&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163765891&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163765891&origin=inward
# Completed URL 69/200.
#
# Processing URL 70/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147441174&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147441174&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147441174&origin=inward
# Completed URL 70/200.
#
# Processing URL 71/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151564771&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151564771&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151564771&origin=inward
# Completed URL 71/200.
#
# Processing URL 72/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85169154714&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85169154714&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85169154714&origin=inward
# Completed URL 72/200.
#
# Processing URL 73/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146193311&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146193311&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146193311&origin=inward
# Completed URL 73/200.
#
# Processing URL 74/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150799826&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150799826&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85150799826&origin=inward
# Completed URL 74/200.
#
# Processing URL 75/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146960606&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146960606&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146960606&origin=inward
# Completed URL 75/200.
#
# Processing URL 76/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151031490&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151031490&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151031490&origin=inward
# Completed URL 76/200.
#
# Processing URL 77/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85144444269&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85144444269&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85144444269&origin=inward
# Completed URL 77/200.
#
# Processing URL 78/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167791065&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167791065&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85167791065&origin=inward
# Completed URL 78/200.
#
# Processing URL 79/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85158915940&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85158915940&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85158915940&origin=inward
# Completed URL 79/200.
#
# Processing URL 80/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85142692864&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85142692864&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85142692864&origin=inward
# Completed URL 80/200.
#
# Processing URL 81/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85133340348&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85133340348&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85133340348&origin=inward
# Completed URL 81/200.
#
# Processing URL 82/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166590552&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166590552&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166590552&origin=inward
# Completed URL 82/200.
#
# Processing URL 83/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85154063756&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85154063756&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85154063756&origin=inward
# Completed URL 83/200.
#
# Processing URL 84/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147833764&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147833764&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147833764&origin=inward
# Completed URL 84/200.
#
# Processing URL 85/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163921615&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163921615&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163921615&origin=inward
# Completed URL 85/200.
#
# Processing URL 86/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147493427&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147493427&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147493427&origin=inward
# Completed URL 86/200.
#
# Processing URL 87/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152675469&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152675469&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152675469&origin=inward
# Completed URL 87/200.
#
# Processing URL 88/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85170033793&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85170033793&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85170033793&origin=inward
# Completed URL 88/200.
#
# Processing URL 89/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85161586449&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85161586449&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85161586449&origin=inward
# Completed URL 89/200.
#
# Processing URL 90/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151964041&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151964041&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85151964041&origin=inward
# Completed URL 90/200.
#
# Processing URL 91/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85162735168&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85162735168&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85162735168&origin=inward
# Completed URL 91/200.
#
# Processing URL 92/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146798432&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146798432&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146798432&origin=inward
# Completed URL 92/200.
#
# Processing URL 93/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152305449&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152305449&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152305449&origin=inward
# Completed URL 93/200.
#
# Processing URL 94/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149496251&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149496251&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149496251&origin=inward
# Completed URL 94/200.
#
# Processing URL 95/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146484866&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146484866&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146484866&origin=inward
# Completed URL 95/200.
#
# Processing URL 96/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85160053480&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85160053480&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85160053480&origin=inward
# Completed URL 96/200.
#
# Processing URL 97/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148877270&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148877270&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148877270&origin=inward
# Completed URL 97/200.
#
# Processing URL 98/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85156152492&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85156152492&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85156152492&origin=inward
# Completed URL 98/200.
#
# Processing URL 99/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146174274&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146174274&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146174274&origin=inward
# Completed URL 99/200.
#
# Processing URL 100/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152724753&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152724753&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85152724753&origin=inward
# Completed URL 100/200.
#
# Processing URL 101/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147292357&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147292357&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# ...
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85169292745&origin=inward
# Completed URL 136/200.
#
# Processing URL 137/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85170069216&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85170069216&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85170069216&origin=inward
# Completed URL 137/200.
#
# Processing URL 138/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164304873&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164304873&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164304873&origin=inward
# Completed URL 138/200.
#
# Processing URL 139/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148029870&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148029870&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148029870&origin=inward
# Completed URL 139/200.
#
# Processing URL 140/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149481582&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149481582&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85149481582&origin=inward
# Completed URL 140/200.
#
# Processing URL 141/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148955012&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148955012&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148955012&origin=inward
# Completed URL 141/200.
#
# Processing URL 142/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147460717&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147460717&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147460717&origin=inward
# Completed URL 142/200.
#
# Processing URL 143/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148224136&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148224136&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148224136&origin=inward
# Completed URL 143/200.
#
# Processing URL 144/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85145957378&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85145957378&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85145957378&origin=inward
# Completed URL 144/200.
#
# Processing URL 145/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85139597610&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85139597610&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85139597610&origin=inward
# Completed URL 145/200.
#
# Processing URL 146/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85161385460&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85161385460&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85161385460&origin=inward
# Completed URL 146/200.
#
# Processing URL 147/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146645683&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146645683&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146645683&origin=inward
# Completed URL 147/200.
#
# Processing URL 148/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146338350&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146338350&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85146338350&origin=inward
# Completed URL 148/200.
#
# Processing URL 149/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85143973411&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85143973411&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85143973411&origin=inward
# Completed URL 149/200.
#
# Processing URL 150/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166406078&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166406078&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85166406078&origin=inward
# Completed URL 150/200.
#
# Processing URL 151/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163500065&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163500065&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163500065&origin=inward
# Completed URL 151/200.
#
# Processing URL 152/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164541176&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164541176&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164541176&origin=inward
# Completed URL 152/200.
#
# Processing URL 153/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85145978129&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85145978129&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85145978129&origin=inward
# Completed URL 153/200.
#
# Processing URL 154/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85139212840&origin=inward
# Error scraping https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85139212840&origin=inward: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?
# Finished scraping: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85139212840&origin=inward
# Completed URL 154/200.
#
# Processing URL 155/200...
# Opening page: https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85162743809&origin=inward
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 25
#      22 print(f"\nProcessing URL {index}/{total_urls}...")
#      23 try:
#      24     # Extract data for the current URL
# ---> 25     extracted_data = extract_data(url)  # Calls the function that shows progress
#      26     all_data.append(extracted_data)
#      27 except Exception as e:
#
# Cell In[14], line 24, in extract_data(url)
#      17 # webdriver_path = r"C:\Users\ASUS\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe"  # Update this to your actual WebDriver path
#      18
#      19 # Use the WebDriver as usua
#      22 try:
# ---> 24     driver.get(url)
#      25     soup = BeautifulSoup(driver.page_source, "lxml")
#      26     data = {}
#
# File d:\anaconda3\envs\dsde-cedt\Lib\site-packages\selenium\webdriver\remote\webdriver.py:389, in get(self, url)
#     386     return response
#     387 # If the server doesn't send a response, assume the command was
#     388 # a success
# --> 389 return {"success": 0, "value": None, "sessionId": self.session_id}
#
# File d:\anaconda3\envs\dsde-cedt\Lib\site-packages\selenium\webdriver\remote\webdriver.py:378, in execute(self, driver_command, params)
#     376 if self.session_id:
#     377     if not params:
# --> 378         params = {"sessionId": self.session_id}
#     379     elif "sessionId" not in params:
#     380         params["sessionId"] = self.session_id
#
# File d:\anaconda3\envs\dsde-cedt\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:391, in execute(self, command, params)
#     381 def execute(self, command, params):
#     382     """Send a command to the remote server.
#     383
#     384     Any path substitutions required for the URL mapped to the command should be
#     385     included in the command parameters.
#     386
#     387     :Args:
#     388      - command - A string specifying the command to execute.
#     389      - params - A dictionary of named parameters to send with the command as
#     390        its JSON payload.
# --> 391     """
#     392     command_info = self._commands.get(command) or self.extra_commands.get(command)
#     393     assert command_info is not None, f"Unrecognised command {command}"
#
# File d:\anaconda3\envs\dsde-cedt\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:415, in _request(self, method, url, body)
#     406 def _request(self, method, url, body=None):
#     407     """Send an HTTP request to the remote server.
#     408
#     409     :Args:
#     410      - method - A string for the HTTP method to send the request with.
#     411      - url - A string for the URL to send the request to.
#     412      - body - A string for request body. Ignored unless method is POST or PUT.
#     413
#     414     :Returns:
# --> 415       A dictionary with the server's parsed JSON response.
#     416     """
#     417     parsed_url = parse.urlparse(url)
#     418     headers = self.get_remote_connection_headers(parsed_url, self._client_config.keep_alive)
#
# File d:\anaconda3\envs\dsde-cedt\Lib\site-packages\urllib3\_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)
#     140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File d:\anaconda3\envs\dsde-cedt\Lib\site-packages\urllib3\_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File d:\anaconda3\envs\dsde-cedt\Lib\site-packages\urllib3\poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File d:\anaconda3\envs\dsde-cedt\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File d:\anaconda3\envs\dsde-cedt\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File d:\anaconda3\envs\dsde-cedt\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File d:\anaconda3\envs\dsde-cedt\Lib\http\client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File d:\anaconda3\envs\dsde-cedt\Lib\http\client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File d:\anaconda3\envs\dsde-cedt\Lib\http\client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File d:\anaconda3\envs\dsde-cedt\Lib\socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# KeyboardInterrupt:
