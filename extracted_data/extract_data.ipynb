# %%
import os
import json
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import csv
import pandas as pd

# %%
def extract_scopus_links(data, links=None):
    """
    Recursively extract all Scopus links from a JSON object, excluding those with 'citedbyresults'.
    """
    if links is None:
        links = set()

    if isinstance(data, dict):
        for key, value in data.items():
            extract_scopus_links(value, links)
    elif isinstance(data, list):
        for item in data:
            extract_scopus_links(item, links)
    elif isinstance(data, str) and "scopus.com" in data and "citedby" not in data:
        links.add(data)

    return links

def process_folders(base_folder, output_file):
    """
    Process all files in subfolders, extracting Scopus links from files containing JSON content.
    """
    collected_links = set()

    # Walk through each folder and file
    for root, dirs, files in os.walk(base_folder):
        for file in files:
            file_path = os.path.join(root, file)
            print(f"Processing folder: {root} | File: {file}")  # Print current folder and file being processed
            try:
                # Try to open and parse the file as JSON, even if it's not a .json file
                with open(file_path, 'r', encoding='utf-8') as f:
                    try:
                        # Try loading the content as JSON
                        json_data = json.load(f)

                        # Extract Scopus links
                        links = extract_scopus_links(json_data)
                        collected_links.update(links)
                    except json.JSONDecodeError:
                        # If the file content is not valid JSON, print a message
                        print(f"Skipping file (not valid JSON): {file_path}")
            except Exception as e:
                print(f"Error processing {file_path}: {e}")

    # Save all collected links to a single file
    with open(output_file, 'w') as outfile:
        outfile.write("\n".join(collected_links))

    print(f"Found {len(collected_links)} Scopus links (excluding 'citedby'). Saved to {output_file}.")

# Step 1: Specify the folder where the extracted files are located
base_folder = 'Project'  # Replace with the path to your extracted files

# Step 2: Define the output file path
output_file = 'scopus_links.txt'  # Output file path for saving the Scopus links

# Step 3: Process the folder and extract Scopus links
process_folders(base_folder, output_file)

# Step 4: Notify that the file is saved
print(f"Scopus links have been saved to {output_file}. You can open it locally.")
# Out:
# Processing folder: Project\2018 | File: 201800000
# Processing folder: Project\2018 | File: 201800001
# Processing folder: Project\2018 | File: 201800002
# Processing folder: Project\2018 | File: 201800003
# Processing folder: Project\2018 | File: 201800004
# Processing folder: Project\2018 | File: 201800005
# Processing folder: Project\2018 | File: 201800006
# Processing folder: Project\2018 | File: 201800007
# Processing folder: Project\2018 | File: 201800008
# Processing folder: Project\2018 | File: 201800009
# Processing folder: Project\2018 | File: 201800010
# Processing folder: Project\2018 | File: 201800011
# Processing folder: Project\2018 | File: 201800012
# Processing folder: Project\2018 | File: 201800013
# Processing folder: Project\2018 | File: 201800014
# Processing folder: Project\2018 | File: 201800015
# Processing folder: Project\2018 | File: 201800016
# Processing folder: Project\2018 | File: 201800017
# Processing folder: Project\2018 | File: 201800018
# Processing folder: Project\2018 | File: 201800019
# Processing folder: Project\2018 | File: 201800020
# Processing folder: Project\2018 | File: 201800021
# Processing folder: Project\2018 | File: 201800022
# Processing folder: Project\2018 | File: 201800023
# Processing folder: Project\2018 | File: 201800024
# Processing folder: Project\2018 | File: 201800025
# Processing folder: Project\2018 | File: 201800026
# Processing folder: Project\2018 | File: 201800027
# Processing folder: Project\2018 | File: 201800028
# Processing folder: Project\2018 | File: 201800029
# Processing folder: Project\2018 | File: 201800030
# Processing folder: Project\2018 | File: 201800031
# Processing folder: Project\2018 | File: 201800032
# Processing folder: Project\2018 | File: 201800033
# Processing folder: Project\2018 | File: 201800034
# Processing folder: Project\2018 | File: 201800035
# Processing folder: Project\2018 | File: 201800036
# Processing folder: Project\2018 | File: 201800037
# Processing folder: Project\2018 | File: 201800038
# Processing folder: Project\2018 | File: 201800039
# Processing folder: Project\2018 | File: 201800040
# Processing folder: Project\2018 | File: 201800041
# Processing folder: Project\2018 | File: 201800042
# Processing folder: Project\2018 | File: 201800043
# Processing folder: Project\2018 | File: 201800044
# Processing folder: Project\2018 | File: 201800045
# Processing folder: Project\2018 | File: 201800046
# Processing folder: Project\2018 | File: 201800047
# Processing folder: Project\2018 | File: 201800048
# Processing folder: Project\2018 | File: 201800049
# Processing folder: Project\2018 | File: 201800050
# Processing folder: Project\2018 | File: 201800051
# Processing folder: Project\2018 | File: 201800052
# Processing folder: Project\2018 | File: 201800053
# Processing folder: Project\2018 | File: 201800054
# Processing folder: Project\2018 | File: 201800055
# Processing folder: Project\2018 | File: 201800056
# Processing folder: Project\2018 | File: 201800057
# Processing folder: Project\2018 | File: 201800058
# Processing folder: Project\2018 | File: 201800059
# Processing folder: Project\2018 | File: 201800060
# Processing folder: Project\2018 | File: 201800061
# Processing folder: Project\2018 | File: 201800062
# Processing folder: Project\2018 | File: 201800063
# Processing folder: Project\2018 | File: 201800064
# Processing folder: Project\2018 | File: 201800065
# Processing folder: Project\2018 | File: 201800066
# Processing folder: Project\2018 | File: 201800067
# Processing folder: Project\2018 | File: 201800068
# Processing folder: Project\2018 | File: 201800069
# Processing folder: Project\2018 | File: 201800070
# Processing folder: Project\2018 | File: 201800071
# Processing folder: Project\2018 | File: 201800072
# Processing folder: Project\2018 | File: 201800073
# Processing folder: Project\2018 | File: 201800074
# Processing folder: Project\2018 | File: 201800075
# Processing folder: Project\2018 | File: 201800076
# Processing folder: Project\2018 | File: 201800077
# Processing folder: Project\2018 | File: 201800078
# Processing folder: Project\2018 | File: 201800079
# Processing folder: Project\2018 | File: 201800080
# Processing folder: Project\2018 | File: 201800081
# Processing folder: Project\2018 | File: 201800082
# Processing folder: Project\2018 | File: 201800083
# Processing folder: Project\2018 | File: 201800084
# Processing folder: Project\2018 | File: 201800085
# Processing folder: Project\2018 | File: 201800086
# Processing folder: Project\2018 | File: 201800087
# Processing folder: Project\2018 | File: 201800088
# Processing folder: Project\2018 | File: 201800089
# Processing folder: Project\2018 | File: 201800090
# Processing folder: Project\2018 | File: 201800091
# Processing folder: Project\2018 | File: 201800092
# Processing folder: Project\2018 | File: 201800093
# Processing folder: Project\2018 | File: 201800094
# Processing folder: Project\2018 | File: 201800095
# Processing folder: Project\2018 | File: 201800096
# Processing folder: Project\2018 | File: 201800097
# Processing folder: Project\2018 | File: 201800098
# Processing folder: Project\2018 | File: 201800099
# Processing folder: Project\2018 | File: 201800100
# Processing folder: Project\2018 | File: 201800101
# Processing folder: Project\2018 | File: 201800102
# Processing folder: Project\2018 | File: 201800103
# Processing folder: Project\2018 | File: 201800104
# Processing folder: Project\2018 | File: 201800105
# Processing folder: Project\2018 | File: 201800106
# Processing folder: Project\2018 | File: 201800107
# Processing folder: Project\2018 | File: 201800108
# Processing folder: Project\2018 | File: 201800109
# Processing folder: Project\2018 | File: 201800110
# Processing folder: Project\2018 | File: 201800111
# Processing folder: Project\2018 | File: 201800112
# Processing folder: Project\2018 | File: 201800113
# Processing folder: Project\2018 | File: 201800114
# Processing folder: Project\2018 | File: 201800115
# Processing folder: Project\2018 | File: 201800116
# Processing folder: Project\2018 | File: 201800117
# Processing folder: Project\2018 | File: 201800118
# Processing folder: Project\2018 | File: 201800119
# Processing folder: Project\2018 | File: 201800120
# Processing folder: Project\2018 | File: 201800121
# Processing folder: Project\2018 | File: 201800122
# Processing folder: Project\2018 | File: 201800123
# Processing folder: Project\2018 | File: 201800124
# Processing folder: Project\2018 | File: 201800125
# Processing folder: Project\2018 | File: 201800126
# Processing folder: Project\2018 | File: 201800127
# Processing folder: Project\2018 | File: 201800128
# Processing folder: Project\2018 | File: 201800129
# Processing folder: Project\2018 | File: 201800130
# Processing folder: Project\2018 | File: 201800131
# Processing folder: Project\2018 | File: 201800132
# Processing folder: Project\2018 | File: 201800133
# Processing folder: Project\2018 | File: 201800134
# Processing folder: Project\2018 | File: 201800135
# Processing folder: Project\2018 | File: 201800136
# Processing folder: Project\2018 | File: 201800137
# Processing folder: Project\2018 | File: 201800138
# Processing folder: Project\2018 | File: 201800139
# Processing folder: Project\2018 | File: 201800140
# Processing folder: Project\2018 | File: 201800141
# Processing folder: Project\2018 | File: 201800142
# Processing folder: Project\2018 | File: 201800143
# Processing folder: Project\2018 | File: 201800144
# Processing folder: Project\2018 | File: 201800145
# Processing folder: Project\2018 | File: 201800146
# Processing folder: Project\2018 | File: 201800147
# Processing folder: Project\2018 | File: 201800148
# Processing folder: Project\2018 | File: 201800149
# Processing folder: Project\2018 | File: 201800150
# Processing folder: Project\2018 | File: 201800151
# Processing folder: Project\2018 | File: 201800152
# Processing folder: Project\2018 | File: 201800153
# Processing folder: Project\2018 | File: 201800154
# Processing folder: Project\2018 | File: 201800155
# Processing folder: Project\2018 | File: 201800156
# Processing folder: Project\2018 | File: 201800157
# Processing folder: Project\2018 | File: 201800158
# Processing folder: Project\2018 | File: 201800159
# Processing folder: Project\2018 | File: 201800160
# Processing folder: Project\2018 | File: 201800161
# Processing folder: Project\2018 | File: 201800162
# Processing folder: Project\2018 | File: 201800163
# Processing folder: Project\2018 | File: 201800164
# Processing folder: Project\2018 | File: 201800165
# Processing folder: Project\2018 | File: 201800166
# Processing folder: Project\2018 | File: 201800167
# Processing folder: Project\2018 | File: 201800168
# Processing folder: Project\2018 | File: 201800169
# Processing folder: Project\2018 | File: 201800170
# Processing folder: Project\2018 | File: 201800171
# Processing folder: Project\2018 | File: 201800172
# Processing folder: Project\2018 | File: 201800173
# Processing folder: Project\2018 | File: 201800174
# Processing folder: Project\2018 | File: 201800175
# Processing folder: Project\2018 | File: 201800176
# Processing folder: Project\2018 | File: 201800177
# Processing folder: Project\2018 | File: 201800178
# Processing folder: Project\2018 | File: 201800179
# Processing folder: Project\2018 | File: 201800180
# Processing folder: Project\2018 | File: 201800181
# Processing folder: Project\2018 | File: 201800182
# Processing folder: Project\2018 | File: 201800183
# Processing folder: Project\2018 | File: 201800184
# Processing folder: Project\2018 | File: 201800185
# Processing folder: Project\2018 | File: 201800186
# Processing folder: Project\2018 | File: 201800187
# Processing folder: Project\2018 | File: 201800188
# Processing folder: Project\2018 | File: 201800189
# Processing folder: Project\2018 | File: 201800190
# Processing folder: Project\2018 | File: 201800191
# Processing folder: Project\2018 | File: 201800192
# Processing folder: Project\2018 | File: 201800193
# Processing folder: Project\2018 | File: 201800194
# Processing folder: Project\2018 | File: 201800195
# Processing folder: Project\2018 | File: 201800196
# Processing folder: Project\2018 | File: 201800197
# Processing folder: Project\2018 | File: 201800198
# Processing folder: Project\2018 | File: 201800199
# Processing folder: Project\2018 | File: 201800200
# Processing folder: Project\2018 | File: 201800201
# Processing folder: Project\2018 | File: 201800202
# Processing folder: Project\2018 | File: 201800203
# Processing folder: Project\2018 | File: 201800204
# Processing folder: Project\2018 | File: 201800205
# Processing folder: Project\2018 | File: 201800206
# Processing folder: Project\2018 | File: 201800207
# Processing folder: Project\2018 | File: 201800208
# Processing folder: Project\2018 | File: 201800209
# Processing folder: Project\2018 | File: 201800210
# Processing folder: Project\2018 | File: 201800211
# Processing folder: Project\2018 | File: 201800212
# Processing folder: Project\2018 | File: 201800213
# Processing folder: Project\2018 | File: 201800214
# Processing folder: Project\2018 | File: 201800215
# Processing folder: Project\2018 | File: 201800216
# Processing folder: Project\2018 | File: 201800217
# Processing folder: Project\2018 | File: 201800218
# Processing folder: Project\2018 | File: 201800219
# Processing folder: Project\2018 | File: 201800220
# Processing folder: Project\2018 | File: 201800221
# Processing folder: Project\2018 | File: 201800222
# Processing folder: Project\2018 | File: 201800223
# Processing folder: Project\2018 | File: 201800224
# Processing folder: Project\2018 | File: 201800225
# Processing folder: Project\2018 | File: 201800226
# Processing folder: Project\2018 | File: 201800227
# Processing folder: Project\2018 | File: 201800228
# Processing folder: Project\2018 | File: 201800229
# Processing folder: Project\2018 | File: 201800230
# Processing folder: Project\2018 | File: 201800231
# Processing folder: Project\2018 | File: 201800232
# Processing folder: Project\2018 | File: 201800233
# Processing folder: Project\2018 | File: 201800234
# Processing folder: Project\2018 | File: 201800235
# Processing folder: Project\2018 | File: 201800236
# Processing folder: Project\2018 | File: 201800237
# Processing folder: Project\2018 | File: 201800238
# Processing folder: Project\2018 | File: 201800239
# Processing folder: Project\2018 | File: 201800240
# Processing folder: Project\2018 | File: 201800241
# Processing folder: Project\2018 | File: 201800242
# Processing folder: Project\2018 | File: 201800243
# Processing folder: Project\2018 | File: 201800244
# Processing folder: Project\2018 | File: 201800245
# Processing folder: Project\2018 | File: 201800246
# Processing folder: Project\2018 | File: 201800247
# Processing folder: Project\2018 | File: 201800248
# Processing folder: Project\2018 | File: 201800249
# Processing folder: Project\2018 | File: 201800250
# Processing folder: Project\2018 | File: 201800251
# Processing folder: Project\2018 | File: 201800252
# Processing folder: Project\2018 | File: 201800253
# Processing folder: Project\2018 | File: 201800254
# Processing folder: Project\2018 | File: 201800255
# Processing folder: Project\2018 | File: 201800256
# Processing folder: Project\2018 | File: 201800257
# Processing folder: Project\2018 | File: 201800258
# Processing folder: Project\2018 | File: 201800259
# Processing folder: Project\2018 | File: 201800260
# Processing folder: Project\2018 | File: 201800261
# Processing folder: Project\2018 | File: 201800262
# Processing folder: Project\2018 | File: 201800263
# Processing folder: Project\2018 | File: 201800264
# Processing folder: Project\2018 | File: 201800265
# Processing folder: Project\2018 | File: 201800266
# Processing folder: Project\2018 | File: 201800267
# Processing folder: Project\2018 | File: 201800268
# Processing folder: Project\2018 | File: 201800269
# Processing folder: Project\2018 | File: 201800270
# Processing folder: Project\2018 | File: 201800271
# Processing folder: Project\2018 | File: 201800272
# Processing folder: Project\2018 | File: 201800273
# Processing folder: Project\2018 | File: 201800274
# Processing folder: Project\2018 | File: 201800275
# Processing folder: Project\2018 | File: 201800276
# Processing folder: Project\2018 | File: 201800277
# Processing folder: Project\2018 | File: 201800278
# Processing folder: Project\2018 | File: 201800279
# Processing folder: Project\2018 | File: 201800280
# Processing folder: Project\2018 | File: 201800281
# Processing folder: Project\2018 | File: 201800282
# Processing folder: Project\2018 | File: 201800283
# Processing folder: Project\2018 | File: 201800284
# Processing folder: Project\2018 | File: 201800285
# Processing folder: Project\2018 | File: 201800286
# Processing folder: Project\2018 | File: 201800287
# Processing folder: Project\2018 | File: 201800288
# Processing folder: Project\2018 | File: 201800289
# Processing folder: Project\2018 | File: 201800290
# Processing folder: Project\2018 | File: 201800291
# Processing folder: Project\2018 | File: 201800292
# Processing folder: Project\2018 | File: 201800293
# Processing folder: Project\2018 | File: 201800294
# Processing folder: Project\2018 | File: 201800295
# Processing folder: Project\2018 | File: 201800296
# Processing folder: Project\2018 | File: 201800297
# Processing folder: Project\2018 | File: 201800298
# Processing folder: Project\2018 | File: 201800299
# Processing folder: Project\2018 | File: 201800300
# Processing folder: Project\2018 | File: 201800301
# Processing folder: Project\2018 | File: 201800302
# Processing folder: Project\2018 | File: 201800303
# Processing folder: Project\2018 | File: 201800304
# Processing folder: Project\2018 | File: 201800305
# Processing folder: Project\2018 | File: 201800306
# Processing folder: Project\2018 | File: 201800307
# Processing folder: Project\2018 | File: 201800308
# Processing folder: Project\2018 | File: 201800309
# Processing folder: Project\2018 | File: 201800310
# Processing folder: Project\2018 | File: 201800311
# Processing folder: Project\2018 | File: 201800312
# Processing folder: Project\2018 | File: 201800313
# Processing folder: Project\2018 | File: 201800314
# Processing folder: Project\2018 | File: 201800315
# Processing folder: Project\2018 | File: 201800316
# Processing folder: Project\2018 | File: 201800317
# Processing folder: Project\2018 | File: 201800318
# Processing folder: Project\2018 | File: 201800319
# Processing folder: Project\2018 | File: 201800320
# Processing folder: Project\2018 | File: 201800321
# Processing folder: Project\2018 | File: 201800322
# Processing folder: Project\2018 | File: 201800323
# Processing folder: Project\2018 | File: 201800324
# Processing folder: Project\2018 | File: 201800325
# Processing folder: Project\2018 | File: 201800326
# Processing folder: Project\2018 | File: 201800327
# Processing folder: Project\2018 | File: 201800328
# Processing folder: Project\2018 | File: 201800329
# Processing folder: Project\2018 | File: 201800330
# Processing folder: Project\2018 | File: 201800331
# Processing folder: Project\2018 | File: 201800332
# Processing folder: Project\2018 | File: 201800333
# Processing folder: Project\2018 | File: 201800334
# Processing folder: Project\2018 | File: 201800335
# Processing folder: Project\2018 | File: 201800336
# Processing folder: Project\2018 | File: 201800337
# Processing folder: Project\2018 | File: 201800338
# Processing folder: Project\2018 | File: 201800339
# Processing folder: Project\2018 | File: 201800340
# Processing folder: Project\2018 | File: 201800341
# Processing folder: Project\2018 | File: 201800342
# Processing folder: Project\2018 | File: 201800343
# Processing folder: Project\2018 | File: 201800344
# Processing folder: Project\2018 | File: 201800345
# Processing folder: Project\2018 | File: 201800346
# Processing folder: Project\2018 | File: 201800347
# Processing folder: Project\2018 | File: 201800348
# Processing folder: Project\2018 | File: 201800349
# Processing folder: Project\2018 | File: 201800350
# Processing folder: Project\2018 | File: 201800351
# Processing folder: Project\2018 | File: 201800352
# Processing folder: Project\2018 | File: 201800353
# Processing folder: Project\2018 | File: 201800354
# Processing folder: Project\2018 | File: 201800355
# Processing folder: Project\2018 | File: 201800356
# Processing folder: Project\2018 | File: 201800357
# Processing folder: Project\2018 | File: 201800358
# Processing folder: Project\2018 | File: 201800359
# Processing folder: Project\2018 | File: 201800360
# Processing folder: Project\2018 | File: 201800361
# Processing folder: Project\2018 | File: 201800362
# Processing folder: Project\2018 | File: 201800363
# Processing folder: Project\2018 | File: 201800364
# Processing folder: Project\2018 | File: 201800365
# Processing folder: Project\2018 | File: 201800366
# Processing folder: Project\2018 | File: 201800367
# Processing folder: Project\2018 | File: 201800368
# Processing folder: Project\2018 | File: 201800369
# Processing folder: Project\2018 | File: 201800370
# Processing folder: Project\2018 | File: 201800371
# Processing folder: Project\2018 | File: 201800372
# Processing folder: Project\2018 | File: 201800373
# Processing folder: Project\2018 | File: 201800374
# Processing folder: Project\2018 | File: 201800375
# Processing folder: Project\2018 | File: 201800376
# Processing folder: Project\2018 | File: 201800377
# Processing folder: Project\2018 | File: 201800378
# Processing folder: Project\2018 | File: 201800379
# Processing folder: Project\2018 | File: 201800380
# Processing folder: Project\2018 | File: 201800381
# Processing folder: Project\2018 | File: 201800382
# Processing folder: Project\2018 | File: 201800383
# Processing folder: Project\2018 | File: 201800384
# Processing folder: Project\2018 | File: 201800385
# Processing folder: Project\2018 | File: 201800386
# Processing folder: Project\2018 | File: 201800387
# Processing folder: Project\2018 | File: 201800388
# Processing folder: Project\2018 | File: 201800389
# Processing folder: Project\2018 | File: 201800390
# Processing folder: Project\2018 | File: 201800391
# Processing folder: Project\2018 | File: 201800392
# Processing folder: Project\2018 | File: 201800393
# Processing folder: Project\2018 | File: 201800394
# Processing folder: Project\2018 | File: 201800395
# Processing folder: Project\2018 | File: 201800396
# Processing folder: Project\2018 | File: 201800397
# Processing folder: Project\2018 | File: 201800398
# Processing folder: Project\2018 | File: 201800399
# Processing folder: Project\2018 | File: 201800400
# Processing folder: Project\2018 | File: 201800401
# Processing folder: Project\2018 | File: 201800402
# Processing folder: Project\2018 | File: 201800403
# Processing folder: Project\2018 | File: 201800404
# Processing folder: Project\2018 | File: 201800405
# Processing folder: Project\2018 | File: 201800406
# Processing folder: Project\2018 | File: 201800407
# Processing folder: Project\2018 | File: 201800408
# Processing folder: Project\2018 | File: 201800409
# Processing folder: Project\2018 | File: 201800410
# Processing folder: Project\2018 | File: 201800411
# Processing folder: Project\2018 | File: 201800412
# Processing folder: Project\2018 | File: 201800413
# Processing folder: Project\2018 | File: 201800414
# Processing folder: Project\2018 | File: 201800415
# Processing folder: Project\2018 | File: 201800416
# Processing folder: Project\2018 | File: 201800417
# Processing folder: Project\2018 | File: 201800418
# Processing folder: Project\2018 | File: 201800419
# Processing folder: Project\2018 | File: 201800420
# Processing folder: Project\2018 | File: 201800421
# Processing folder: Project\2018 | File: 201800422
# Processing folder: Project\2018 | File: 201800423
# Processing folder: Project\2018 | File: 201800424
# Processing folder: Project\2018 | File: 201800425
# Processing folder: Project\2018 | File: 201800426
# Processing folder: Project\2018 | File: 201800427
# Processing folder: Project\2018 | File: 201800428
# Processing folder: Project\2018 | File: 201800429
# Processing folder: Project\2018 | File: 201800430
# Processing folder: Project\2018 | File: 201800431
# Processing folder: Project\2018 | File: 201800432
# Processing folder: Project\2018 | File: 201800433
# Processing folder: Project\2018 | File: 201800434
# Processing folder: Project\2018 | File: 201800435
# Processing folder: Project\2018 | File: 201800436
# Processing folder: Project\2018 | File: 201800437
# Processing folder: Project\2018 | File: 201800438
# Processing folder: Project\2018 | File: 201800439
# Processing folder: Project\2018 | File: 201800440
# Processing folder: Project\2018 | File: 201800441
# Processing folder: Project\2018 | File: 201800442
# Processing folder: Project\2018 | File: 201800443
# Processing folder: Project\2018 | File: 201800444
# Processing folder: Project\2018 | File: 201800445
# Processing folder: Project\2018 | File: 201800446
# Processing folder: Project\2018 | File: 201800447
# Processing folder: Project\2018 | File: 201800448
# Processing folder: Project\2018 | File: 201800449
# Processing folder: Project\2018 | File: 201800450
# Processing folder: Project\2018 | File: 201800451
# Processing folder: Project\2018 | File: 201800452
# Processing folder: Project\2018 | File: 201800453
# Processing folder: Project\2018 | File: 201800454
# Processing folder: Project\2018 | File: 201800455
# Processing folder: Project\2018 | File: 201800456
# Processing folder: Project\2018 | File: 201800457
# Processing folder: Project\2018 | File: 201800458
# Processing folder: Project\2018 | File: 201800459
# Processing folder: Project\2018 | File: 201800460
# Processing folder: Project\2018 | File: 201800461
# Processing folder: Project\2018 | File: 201800462
# Processing folder: Project\2018 | File: 201800463
# Processing folder: Project\2018 | File: 201800464
# Processing folder: Project\2018 | File: 201800465
# Processing folder: Project\2018 | File: 201800466
# Processing folder: Project\2018 | File: 201800467
# Processing folder: Project\2018 | File: 201800468
# Processing folder: Project\2018 | File: 201800469
# Processing folder: Project\2018 | File: 201800470
# Processing folder: Project\2018 | File: 201800471
# Processing folder: Project\2018 | File: 201800472
# Processing folder: Project\2018 | File: 201800473
# Processing folder: Project\2018 | File: 201800474
# Processing folder: Project\2018 | File: 201800475
# Processing folder: Project\2018 | File: 201800476
# Processing folder: Project\2018 | File: 201800477
# Processing folder: Project\2018 | File: 201800478
# Processing folder: Project\2018 | File: 201800479
# Processing folder: Project\2018 | File: 201800480
# Processing folder: Project\2018 | File: 201800481
# Processing folder: Project\2018 | File: 201800482
# Processing folder: Project\2018 | File: 201800483
# Processing folder: Project\2018 | File: 201800484
# Processing folder: Project\2018 | File: 201800485
# Processing folder: Project\2018 | File: 201800486
# Processing folder: Project\2018 | File: 201800487
# Processing folder: Project\2018 | File: 201800488
# Processing folder: Project\2018 | File: 201800489
# Processing folder: Project\2018 | File: 201800490
# Processing folder: Project\2018 | File: 201800491
# Processing folder: Project\2018 | File: 201800492
# Processing folder: Project\2018 | File: 201800493
# Processing folder: Project\2018 | File: 201800494
# Processing folder: Project\2018 | File: 201800495
# Processing folder: Project\2018 | File: 201800496
# Processing folder: Project\2018 | File: 201800497
# Processing folder: Project\2018 | File: 201800498
# Processing folder: Project\2018 | File: 201800499
# Processing folder: Project\2018 | File: 201800500
# Processing folder: Project\2018 | File: 201800501
# Processing folder: Project\2018 | File: 201800502
# Processing folder: Project\2018 | File: 201800503
# Processing folder: Project\2018 | File: 201800504
# Processing folder: Project\2018 | File: 201800505
# Processing folder: Project\2018 | File: 201800506
# Processing folder: Project\2018 | File: 201800507
# Processing folder: Project\2018 | File: 201800508
# Processing folder: Project\2018 | File: 201800509
# Processing folder: Project\2018 | File: 201800510
# Processing folder: Project\2018 | File: 201800511
# Processing folder: Project\2018 | File: 201800512
# Processing folder: Project\2018 | File: 201800513
# Processing folder: Project\2018 | File: 201800514
# Processing folder: Project\2018 | File: 201800515
# Processing folder: Project\2018 | File: 201800516
# Processing folder: Project\2018 | File: 201800517
# Processing folder: Project\2018 | File: 201800518
# Processing folder: Project\2018 | File: 201800519
# Processing folder: Project\2018 | File: 201800520
# Processing folder: Project\2018 | File: 201800521
# Processing folder: Project\2018 | File: 201800522
# Processing folder: Project\2018 | File: 201800523
# Processing folder: Project\2018 | File: 201800524
# Processing folder: Project\2018 | File: 201800525
# Processing folder: Project\2018 | File: 201800526
# Processing folder: Project\2018 | File: 201800527
# Processing folder: Project\2018 | File: 201800528
# Processing folder: Project\2018 | File: 201800529
# Processing folder: Project\2018 | File: 201800530
# Processing folder: Project\2018 | File: 201800531
# Processing folder: Project\2018 | File: 201800532
# Processing folder: Project\2018 | File: 201800533
# Processing folder: Project\2018 | File: 201800534
# Processing folder: Project\2018 | File: 201800535
# Processing folder: Project\2018 | File: 201800536
# Processing folder: Project\2018 | File: 201800537
# Processing folder: Project\2018 | File: 201800538
# Processing folder: Project\2018 | File: 201800539
# Processing folder: Project\2018 | File: 201800540
# Processing folder: Project\2018 | File: 201800541
# Processing folder: Project\2018 | File: 201800542
# Processing folder: Project\2018 | File: 201800543
# Processing folder: Project\2018 | File: 201800544
# Processing folder: Project\2018 | File: 201800545
# Processing folder: Project\2018 | File: 201800546
# Processing folder: Project\2018 | File: 201800547
# Processing folder: Project\2018 | File: 201800548
# Processing folder: Project\2018 | File: 201800549
# Processing folder: Project\2018 | File: 201800550
# Processing folder: Project\2018 | File: 201800551
# Processing folder: Project\2018 | File: 201800552
# Processing folder: Project\2018 | File: 201800553
# Processing folder: Project\2018 | File: 201800554
# Processing folder: Project\2018 | File: 201800555
# Processing folder: Project\2018 | File: 201800556
# Processing folder: Project\2018 | File: 201800557
# Processing folder: Project\2018 | File: 201800558
# Processing folder: Project\2018 | File: 201800559
# Processing folder: Project\2018 | File: 201800560
# Processing folder: Project\2018 | File: 201800561
# Processing folder: Project\2018 | File: 201800562
# Processing folder: Project\2018 | File: 201800563
# Processing folder: Project\2018 | File: 201800564
# Processing folder: Project\2018 | File: 201800565
# Processing folder: Project\2018 | File: 201800566
# Processing folder: Project\2018 | File: 201800567
# Processing folder: Project\2018 | File: 201800568
# Processing folder: Project\2018 | File: 201800569
# Processing folder: Project\2018 | File: 201800570
# Processing folder: Project\2018 | File: 201800571
# Processing folder: Project\2018 | File: 201800572
# Processing folder: Project\2018 | File: 201800573
# Processing folder: Project\2018 | File: 201800574
# Processing folder: Project\2018 | File: 201800575
# Processing folder: Project\2018 | File: 201800576
# Processing folder: Project\2018 | File: 201800577
# Processing folder: Project\2018 | File: 201800578
# Processing folder: Project\2018 | File: 201800579
# Processing folder: Project\2018 | File: 201800580
# Processing folder: Project\2018 | File: 201800581
# Processing folder: Project\2018 | File: 201800582
# Processing folder: Project\2018 | File: 201800583
# Processing folder: Project\2018 | File: 201800584
# Processing folder: Project\2018 | File: 201800585
# Processing folder: Project\2018 | File: 201800586
# Processing folder: Project\2018 | File: 201800587
# Processing folder: Project\2018 | File: 201800588
# Processing folder: Project\2018 | File: 201800589
# Processing folder: Project\2018 | File: 201800590
# Processing folder: Project\2018 | File: 201800591
# Processing folder: Project\2018 | File: 201800592
# Processing folder: Project\2018 | File: 201800593
# Processing folder: Project\2018 | File: 201800594
# Processing folder: Project\2018 | File: 201800595
# Processing folder: Project\2018 | File: 201800596
# Processing folder: Project\2018 | File: 201800597
# Processing folder: Project\2018 | File: 201800598
# Processing folder: Project\2018 | File: 201800599
# Processing folder: Project\2018 | File: 201800600
# Processing folder: Project\2018 | File: 201800601
# Processing folder: Project\2018 | File: 201800602
# Processing folder: Project\2018 | File: 201800603
# Processing folder: Project\2018 | File: 201800604
# Processing folder: Project\2018 | File: 201800605
# Processing folder: Project\2018 | File: 201800606
# Processing folder: Project\2018 | File: 201800607
# Processing folder: Project\2018 | File: 201800608
# Processing folder: Project\2018 | File: 201800609
# Processing folder: Project\2018 | File: 201800610
# Processing folder: Project\2018 | File: 201800611
# Processing folder: Project\2018 | File: 201800612
# Processing folder: Project\2018 | File: 201800613
# Processing folder: Project\2018 | File: 201800614
# Processing folder: Project\2018 | File: 201800615
# Processing folder: Project\2018 | File: 201800616
# Processing folder: Project\2018 | File: 201800617
# Processing folder: Project\2018 | File: 201800618
# Processing folder: Project\2018 | File: 201800619
# Processing folder: Project\2018 | File: 201800620
# Processing folder: Project\2018 | File: 201800621
# Processing folder: Project\2018 | File: 201800622
# Processing folder: Project\2018 | File: 201800623
# Processing folder: Project\2018 | File: 201800624
# Processing folder: Project\2018 | File: 201800625
# Processing folder: Project\2018 | File: 201800626
# Processing folder: Project\2018 | File: 201800627
# Processing folder: Project\2018 | File: 201800628
# Processing folder: Project\2018 | File: 201800629
# Processing folder: Project\2018 | File: 201800630
# Processing folder: Project\2018 | File: 201800631
# Processing folder: Project\2018 | File: 201800632
# Processing folder: Project\2018 | File: 201800633
# Processing folder: Project\2018 | File: 201800634
# Processing folder: Project\2018 | File: 201800635
# Processing folder: Project\2018 | File: 201800636
# Processing folder: Project\2018 | File: 201800637
# Processing folder: Project\2018 | File: 201800638
# Processing folder: Project\2018 | File: 201800639
# Processing folder: Project\2018 | File: 201800640
# Processing folder: Project\2018 | File: 201800641
# Processing folder: Project\2018 | File: 201800642
# Processing folder: Project\2018 | File: 201800643
# Processing folder: Project\2018 | File: 201800644
# Processing folder: Project\2018 | File: 201800645
# Processing folder: Project\2018 | File: 201800646
# Processing folder: Project\2018 | File: 201800647
# Processing folder: Project\2018 | File: 201800648
# Processing folder: Project\2018 | File: 201800649
# Processing folder: Project\2018 | File: 201800650
# Processing folder: Project\2018 | File: 201800651
# Processing folder: Project\2018 | File: 201800652
# Processing folder: Project\2018 | File: 201800653
# Processing folder: Project\2018 | File: 201800654
# Processing folder: Project\2018 | File: 201800655
# Processing folder: Project\2018 | File: 201800656
# Processing folder: Project\2018 | File: 201800657
# Processing folder: Project\2018 | File: 201800658
# Processing folder: Project\2018 | File: 201800659
# Processing folder: Project\2018 | File: 201800660
# Processing folder: Project\2018 | File: 201800661
# Processing folder: Project\2018 | File: 201800662
# Processing folder: Project\2018 | File: 201800663
# Processing folder: Project\2018 | File: 201800664
# Processing folder: Project\2018 | File: 201800665
# Processing folder: Project\2018 | File: 201800666
# Processing folder: Project\2018 | File: 201800667
# Processing folder: Project\2018 | File: 201800668
# Processing folder: Project\2018 | File: 201800669
# Processing folder: Project\2018 | File: 201800670
# Processing folder: Project\2018 | File: 201800671
# Processing folder: Project\2018 | File: 201800672
# Processing folder: Project\2018 | File: 201800673
# Processing folder: Project\2018 | File: 201800674
# Processing folder: Project\2018 | File: 201800675
# Processing folder: Project\2018 | File: 201800676
# Processing folder: Project\2018 | File: 201800677
# Processing folder: Project\2018 | File: 201800678
# Processing folder: Project\2018 | File: 201800679
# Processing folder: Project\2018 | File: 201800680
# Processing folder: Project\2018 | File: 201800681
# Processing folder: Project\2018 | File: 201800682
# Processing folder: Project\2018 | File: 201800683
# Processing folder: Project\2018 | File: 201800684
# Processing folder: Project\2018 | File: 201800685
# Processing folder: Project\2018 | File: 201800686
# Processing folder: Project\2018 | File: 201800687
# Processing folder: Project\2018 | File: 201800688
# Processing folder: Project\2018 | File: 201800689
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-cec4834c873e> in <module>
#      57
#      58 # Step 3: Process the folder and extract Scopus links
# ---> 59 process_folders(base_folder, output_file)
#      60
#      61 # Step 4: Notify that the file is saved
#
# <ipython-input-3-cec4834c873e> in process_folders(base_folder, output_file)
#      40                     except json.JSONDecodeError:
#      41                         # If the file content is not valid JSON, print a message
# ---> 42                         print(f"Skipping file (not valid JSON): {file_path}")
#      43             except Exception as e:
#      44                 print(f"Error processing {file_path}: {e}")
#
# KeyboardInterrupt:

# %%
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->\n<head>\n<title>Attention Required! | Cloudflare</title>\n<meta charset="UTF-8" />\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n<meta name="robots" content="noindex, nofollow" />\n<meta name="viewport" content="width=device-width,initial-scale=1" />\n<link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/cf.errors.css" />\n<!--[if lt IE 9]><link rel="stylesheet" id=\'cf_styles-ie-css\' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->\n<style>body{margin:0;padding:0}</style>\n\n\n<!--[if gte IE 10]><!-->\n<script>\n  if (!navigator.cookieEnabled) {\n    window.addEventListener(\'DOMContentLoaded\', function () {\n      var cookieEl = document.getElementById(\'cookie-alert\');\n      cookieEl.style.display = \'block\';\n    })\n  }\n</script>\n<!--<![endif]-->\n\n\n</head>\n<body>\n  <div id="cf-wrapper">\n    <div class="cf-alert cf-alert-error cf-cookie-error" id="cookie-alert" data-translate="enable_cookies">Please enable cookies.</div>\n    <div id="cf-error-details" class="cf-error-details-wrapper">\n      <div class="cf-wrapper cf-header cf-error-overview">\n        <h1 data-translate="block_headline">Sorry, you have been blocked</h1>\n        <h2 class="cf-subheadline"><span data-translate="unable_to_access">You are unable to access</span> scopus.com</h2>\n      </div><!-- /.header -->\n\n      <div class="cf-section cf-highlight">\n        <div class="cf-wrapper">\n          <div class="cf-screenshot-container cf-screenshot-full">\n            \n              <span class="cf-no-screenshot error"></span>\n            \n          </div>\n        </div>\n      </div><!-- /.captcha-container -->\n\n      <div class="cf-section cf-wrapper">\n        <div class="cf-columns two">\n          <div class="cf-column">\n            <h2 data-translate="blocked_why_headline">Why have I been blocked?</h2>\n\n            <p data-translate="blocked_why_detail">This website is using a security service to protect itself from online attacks. The action you just performed triggered the security solution. There are several actions that could trigger this block including submitting a certain word or phrase, a SQL command or malformed data.</p>\n          </div>\n\n          <div class="cf-column">\n            <h2 data-translate="blocked_resolve_headline">What can I do to resolve this?</h2>\n\n            <p data-translate="blocked_resolve_detail">You can email the site owner to let them know you were blocked. Please include what you were doing when this page came up and the Cloudflare Ray ID found at the bottom of this page.</p>\n          </div>\n        </div>\n      </div><!-- /.section -->\n\n      <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">\n  <p class="text-13">\n    <span class="cf-footer-item sm:block sm:mb-1">Cloudflare Ray ID: <strong class="font-semibold">8e62e3277eaea1ae</strong></span>\n    <span class="cf-footer-separator sm:hidden">&bull;</span>\n    <span id="cf-footer-item-ip" class="cf-footer-item hidden sm:block sm:mb-1">\n      Your IP:\n      <button type="button" id="cf-footer-ip-reveal" class="cf-footer-ip-reveal-btn">Click to reveal</button>\n      <span class="hidden" id="cf-footer-ip">125.24.202.248</span>\n      <span class="cf-footer-separator sm:hidden">&bull;</span>\n    </span>\n    <span class="cf-footer-item sm:block sm:mb-1"><span>Performance &amp; security by</span> <a rel="noopener noreferrer" href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" target="_blank">Cloudfl ...

# %%
def extract_data(url):
    chrome_options = Options()
    chrome_options.add_argument("--disable-gpu")  # Disable GPU acceleration (useful for some environments)

# Specify path to chromedriver if necessary, e.g., 'path/to/chromedriver'
    driver = webdriver.Chrome(executable_path=r"C:\Users\ASUS\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe", options=chrome_options)

    driver.get(url)
    soup = BeautifulSoup(driver.page_source, "lxml")
    data = {}

    # Extraction logic (same as your provided code)
    h2_elements = soup.select('h2')
    for h2 in h2_elements:
        inner_text = h2.get_text(strip=True)
        data["title"] = inner_text if inner_text else ""

    author_section = soup.find('section', {'id': 'authorlist'})
    if author_section:
        author_tags = author_section.find_all('span', {'class': 'previewTxt'})
        authors = [author_tag.get_text(strip=True) for author_tag in author_tags if author_tag.get_text(strip=True)]
        data["authors"] = authors if authors else []
    else:
        data["authors"] = []

    journal_info_span = soup.find('span', {'id': 'journalInfo'})
    data["article_info"] = journal_info_span.get_text(strip=True) if journal_info_span else ""

    abstract_section = soup.find('section', {'id': 'abstractSection'})
    if abstract_section:
        p_tag = abstract_section.find('p')
        data["abstract"] = p_tag.get_text(strip=True) if p_tag else ""
    else:
        data["abstract"] = ""

    span_tag = soup.find('span', {'id': 'guestAccessSourceTitle'})
    data["categories/keyword"] = span_tag.get_text(strip=True) if span_tag else ""

    citation_ul = soup.find('ul', {'id': 'citationInfo'})
    citation_info = {}
    citation_fields = ["ISSN", "Source Type", "Original Language"]
    if citation_ul:
        li_tags = citation_ul.find_all('li')
        for i, li in enumerate(li_tags):
            strong_tag = li.find('strong')
            if strong_tag:
                strong_tag.extract()
            clean_text = li.get_text(strip=True)
            if i < len(citation_fields):
                citation_info[citation_fields[i]] = clean_text
    data["citation_info"] = citation_info

    document_ul = soup.find('ul', {'id': 'documentInfo'})
    document_info = {}
    document_fields = ["Document Type", "Publisher"]
    if document_ul:
        li_tags = document_ul.find_all('li')
        for i, li in enumerate(li_tags):
            strong_tag = li.find('strong')
            if strong_tag:
                strong_tag.extract()
            clean_text = li.get_text(strip=True)
            if i < len(document_fields):
                document_info[document_fields[i]] = clean_text
    data["document_info"] = document_info if document_info else {}

    author_tags = soup.find_all('span', {'class': 'badges'})
    authors = [author_tag.get_text(strip=True) for author_tag in author_tags if author_tag.get_text(strip=True)]
    data["author_tags"] = authors if authors else []

    affiliation_section = soup.find('section', {'id': 'affiliationlist'})
    if affiliation_section:
        affiliation_tags = affiliation_section.find_all('li')
        affiliations = [affiliation_tag.get_text(strip=True) for affiliation_tag in affiliation_tags if affiliation_tag.get_text(strip=True)]
        data["affiliations"] = affiliations if affiliations else []
    else:
        data["affiliations"] = []

    funding_rows = soup.find_all('tr', {'class': 'lightGreyBorderBottom'})
    funding_data = []
    for funding_row in funding_rows:
        td_tags = funding_row.find_all('td')
        funding_info = {"Funding Sponsor": "", "Funding Number": "", "Acronym": ""}
        if len(td_tags) >= 3:
            funding_info["Funding Sponsor"] = td_tags[0].get_text(strip=True) if td_tags[0] else ""
            funding_info["Funding Number"] = td_tags[1].get_text(strip=True) if td_tags[1] else ""
            funding_info["Acronym"] = td_tags[2].get_text(strip=True) if td_tags[2] else ""
        funding_data.append(funding_info)
    data["funding"] = funding_data if funding_data else []
    driver.quit()

    return data

# %%
# with open('scopus_links.txt', 'r') as file:
#     urls = [line.strip() for line in file if line.strip()]

# # Extract data from all URLs
# all_data = []
# for url in urls:
#     try:
#         extracted_data = extract_data(url)
#         all_data.append(extracted_data)
#     except Exception as e:
#         print(f"Error processing URL {url}: {e}")

# # Convert data to a pandas DataFrame
# df = pd.DataFrame(all_data)

# # Save to a CSV file
# df.to_csv('output.csv', index=False)

# # Close the driver

# print("Data extraction complete. Saved to output.csv.")

with open('scopus_links.txt', 'r') as file:
    urls = [line.strip() for line in file if line.strip()]

# Test only the first 5 links
test_urls = urls

# Extract data from the test URLs
all_data = []
for url in test_urls:
    try:
        extracted_data = extract_data(url)
        all_data.append(extracted_data)
    except Exception as e:
        print(f"Error processing URL {url}: {e}")

# Convert data to a pandas DataFrame
df = pd.DataFrame(all_data)

# Save to a CSV file
df.to_csv('test_output.csv', index=False)

print("Data extraction for all URLs complete. Saved to test_output.csv.")
# Out:
# Error processing URL Results from Scopus, 2017 September 17 Retrieved from: https://scopus.com.: Message: invalid argument
#   (Session info: chrome=131.0.6778.85)
#
# Error processing URL Durango-Cohen, E.J., Balasubramanian, S.K., Effective segmentation of university alumni: Mining contribution data with finite-mixture models. Research in Higher Education 56 (2014), 78–104 Retrieved from http://www.scopus.com/inward/record.url?eid=2-s2.0-84901580676&partnerID=40&md5=b271fa0bfc55ea84b325b4fab5f01157.: Message: invalid argument
#   (Session info: chrome=131.0.6778.85)
#
# Data extraction for all URLs complete. Saved to test_output.csv.
